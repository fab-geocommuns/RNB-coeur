# %% [markdown]
# # Inspecteur d'un objet BuildingGuess
#
# Ce notebook sert principalement à récupérer les vrais résultats des GeocoderHandler pour pouvoir en fabriquer des mocks plus facilement

# %%
import os
from pprint import pprint
from batid.services.search_bdg import BuildingGuess, PhotonGeocodingHandler

# necessary for SQL query execution from Jupyter
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
address = "3  impasse simard, Grenoble"
name = None

search = BuildingGuess()
search.set_params(address=address, name=name)

results = search.get_queryset()

print("-------- Search params --------")

# All params
pprint(search.params.__dict__)

# Focus on points
# BAN Point
print('-- BAN point --')
p = None
if search.params._ban_point:
    p = search.params._ban_point.transform(4326, clone=True)
print(p)

# OSM Point
print("-- OSM point --")
p = None
if search.params._osm_point:
    p = search.params._osm_point.transform(4326, clone=True)
print(p)

print("")
print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>")
print("")

print("-------- Results --------")

for bdg in results:
    print("---")
    print(f"RNB ID : {bdg.rnb_id}")
    print(f"Score : {bdg.score}")
    

print("")
print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>")
print("")

print("-------- Geocoding handlers --------")

print("-- OSM Photon Geocoding --")
photon_handler = PhotonGeocodingHandler()

print('-- Photon Query')
photon_params = photon_handler.geocode_params(search.params)
pprint(photon_params)

print('-- Photon Results')
photon_results = photon_handler.geocode(search.params)
pprint(photon_results)
# Out:
# -------- Search params --------
# {'_BuildingSearchParams__ban_handler_cls': <class 'batid.services.search_bdg.BANGeocodingHandler'>,
#  '_BuildingSearchParams__errors': [],
#  '_BuildingSearchParams__osm_handler_cls': <class 'batid.services.search_bdg.PhotonGeocodingHandler'>,
#  '_ban_id': '38185_6400_00003',
#  '_ban_point': <Point object at 0xffff57ba6690>,
#  '_city_poly': None,
#  '_osm_point': None,
#  'address': '3  impasse simard, Grenoble',
#  'allowed_status': ['ongoingConstruction',
#                     'constructed',
#                     'ongoingChange',
#                     'notUsable',
#                     'demolished'],
#  'bb': None,
#  'insee_code': None,
#  'name': None,
#  'page': 1,
#  'point': None,
#  'poly': None,
#  'rnb_id': None,
#  'sort': None,
#  'status': []}
# -- BAN point --
# SRID=4326;POINT (5.736469 45.179156)
# -- OSM point --
# None
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# -------- Results --------
# ---
# RNB ID : HL1Z3UGLNDBT
# Score : 8.0
# ---
# RNB ID : GBMUYQ7DEVXN
# Score : 2.134904593000486
# ---
# RNB ID : 2VEYMGZF8JD8
# Score : 2.1337483553674
# ---
# RNB ID : EHGBHEFMNCLG
# Score : 2.1086665500859203
# ---
# RNB ID : QTH6CQE95YQF
# Score : 2.095153628000294
# ---
# RNB ID : LFKBNTH4ASP9
# Score : 2.0778949718751734
# ---
# RNB ID : 1GH7QTVAPHWU
# Score : 2.0734002579415716
# ---
# RNB ID : PKL3PMYKVUWN
# Score : 2.061471718190103
# ---
# RNB ID : H9NAP2SUQHHH
# Score : 2.0571428727723746
# ---
# RNB ID : M4YDQXDMND3J
# Score : 2.0570803084565985
# ---
# RNB ID : 3N63FW9UQ9SD
# Score : 2.0525635505383697
# ---
# RNB ID : CCL26S358DD8
# Score : 2.052265500705368
# ---
# RNB ID : LX8WXEFHJL97
# Score : 2.050836262880411
# ---
# RNB ID : 2Y2RCL9UU9Q8
# Score : 2.049405305007618
# ---
# RNB ID : LYG27R6QLHP9
# Score : 2.04574745481095
# ---
# RNB ID : 442W6ZQU5GFK
# Score : 2.0450738593369815
# ---
# RNB ID : 8TSD1UHA9RTA
# Score : 2.0393614090595578
# ---
# RNB ID : LJF9M21H1KQZ
# Score : 2.037957684856962
# ---
# RNB ID : UNRJRPWHZRWE
# Score : 2.0357030092579294
# ---
# RNB ID : FVY7HYNMNSUA
# Score : 2.0348472764149768
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# -------- Geocoding handlers --------
# -- OSM Photon Geocoding --
# -- Photon Query
# {'lang': 'fr', 'lat': 45.179156, 'limit': 1, 'lon': 5.736469, 'q': None}
# -- Photon Results
# None
