# %%
import os
import json
from pprint import pprint
from batid.services.geocoders import BanGeocoder
# necessary for SQL query execution from Jupyter
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
fetcher = BanGeocoder()
results = fetcher.geocode({'q':"76 AVENUE DE SAINT-JUST 13013 MARSEILLE"})

data = json.loads(results.text)
pprint(data)
# Out:
# {'attribution': 'BAN',
#  'features': [{'geometry': {'coordinates': [5.405392, 43.317277],
#                             'type': 'Point'},
#                'properties': {'city': 'Marseille',
#                               'citycode': '13213',
#                               'context': '13, Bouches-du-Rhône, '
#                                          "Provence-Alpes-Côte d'Azur",
#                               'district': 'Marseille 13e Arrondissement',
#                               'housenumber': '76',
#                               'id': '13213_8376_00076',
#                               'importance': 0.64494,
#                               'label': '76 Avenue de saint just 13013 '
#                                        'Marseille',
#                               'name': '76 Avenue de saint just',
#                               'postcode': '13013',
#                               'score': 0.9677218181818181,
#                               'street': 'Avenue de saint just',
#                               'type': 'housenumber',
#                               'x': 895208.49,
#                               'y': 6249431.21},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [5.411315, 43.318156],
#                             'type': 'Point'},
#                'properties': {'city': 'Marseille',
#                               'citycode': '13213',
#                               'context': '13, Bouches-du-Rhône, '
#                                          "Provence-Alpes-Côte d'Azur",
#                               'district': 'Marseille 13e Arrondissement',
#                               'id': '13213_7r175l',
#                               'importance': 0.57162,
#                               'label': 'Traverse de saint just 13013 Marseille',
#                               'name': 'Traverse de saint just',
#                               'postcode': '13013',
#                               'score': 0.6608449471458774,
#                               'street': 'Traverse de saint just',
#                               'type': 'street',
#                               'x': 895686.04,
#                               'y': 6249543.54},
#                'type': 'Feature'}],
#  'licence': 'ETALAB-2.0',
#  'limit': 5,
#  'query': '76 AVENUE DE SAINT-JUST 13013 MARSEILLE',
#  'type': 'FeatureCollection',
#  'version': 'draft'}

# %%
fetcher.reverse(45.3616477, 5.5930080)
# Out:
# {'type': 'FeatureCollection',
#  'version': 'draft',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [5.593247, 45.361812]},
#    'properties': {'label': '14 Rue Alban et Émilienne Fagot 38500 Voiron',
#     'score': 0.9999997273665291,
#     'housenumber': '14',
#     'id': '38563_0018_00014',
#     'name': '14 Rue Alban et Émilienne Fagot',
#     'postcode': '38500',
#     'citycode': '38563',
#     'x': 902990.08,
#     'y': 6476935.37,
#     'city': 'Voiron',
#     'context': '38, Isère, Auvergne-Rhône-Alpes',
#     'type': 'housenumber',
#     'importance': 0.52155,
#     'street': 'Rue Alban et Émilienne Fagot',
#     'distance': 26}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [5.593943, 45.361776]},
#    'properties': {'label': '70 Boulevard Franklin Roosevelt 38500 Voiron',
#     'score': 0.9999977868299292,
#     'housenumber': '70',
#     'id': '38563_0550_00070',
#     'name': '70 Boulevard Franklin Roosevelt',
#     'postcode': '38500',
#     'citycode': '38563',
#     'x': 903044.67,
#     'y': 6476933.17,
#     'city': 'Voiron',
#     'context': '38, Isère, Auvergne-Rhône-Alpes',
#     'type': 'housenumber',
#     'importance': 0.5933,
#     'street': 'Boulevard Franklin Roosevelt',
#     'distance': 74}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [5.594034, 45.361382]},
#    'properties': {'label': '3 Rue Clément Chamarier 38500 Voiron',
#     'score': 0.9999970842439333,
#     'housenumber': '3',
#     'id': '38563_0326_00003',
#     'name': '3 Rue Clément Chamarier',
#     'postcode': '38500',
#     'citycode': '38563',
#     'x': 903053.23,
#     'y': 6476889.67,
#     'city': 'Voiron',
#     'context': '38, Isère, Auvergne-Rhône-Alpes',
#     'type': 'housenumber',
#     'importance': 0.496,
#     'street': 'Rue Clément Chamarier',
#     'distance': 85}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [5.591544, 45.361953]},
#    'properties': {'label': 'Jardin de Ville 38500 Voiron',
#     'score': 0.999994313040479,
#     'type': 'locality',
#     'importance': 0.47573,
#     'id': '38563_77c2fj',
#     'name': 'Jardin de Ville',
#     'postcode': '38500',
#     'citycode': '38563',
#     'x': 902856.31,
#     'y': 6476946.65,
#     'city': 'Voiron',
#     'context': '38, Isère, Auvergne-Rhône-Alpes',
#     'locality': 'Jardin de Ville',
#     'distance': 119}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [5.59284, 45.36293]},
#    'properties': {'label': '32 Rue Mainssieux 38500 Voiron',
#     'score': 0.999991809195023,
#     'housenumber': '32',
#     'id': '38563_0987_00032',
#     'name': '32 Rue Mainssieux',
#     'postcode': '38500',
#     'citycode': '38563',
#     'x': 902954.16,
#     'y': 6477058.42,
#     'city': 'Voiron',
#     'context': '38, Isère, Auvergne-Rhône-Alpes',
#     'type': 'housenumber',
#     'importance': 0.55094,
#     'street': 'Rue Mainssieux',
#     'distance': 143}}],
#  'attribution': 'BAN',
#  'licence': 'ETALAB-2.0',
#  'center': [5.593008, 45.3616477],
#  'limit': 1}
