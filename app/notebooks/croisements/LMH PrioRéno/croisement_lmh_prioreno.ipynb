# %% [markdown]
# **Questions**
#
# - Combien d’ID RNB sont partagés entre le bailleur et PrioRéno ?
# - Combien sont juste dans un des deux jeu de données ?
# - Est-ce que pour un ID RNB donné le bailleur social et PrioRéno LS parlent du même bâtiment physique.

# %%
import pandas as pd

bailleur_path = 'LMH_par_LMH.xlsx'
prioreno_path = 'LMH_dans_PrioReno.xlsx'

# %% [markdown]
# ## Colonnes dispo

# %%
df_bailleur_raw = pd.read_excel(bailleur_path)
df_prioreno_raw = pd.read_excel(prioreno_path)

print("Colonnes - bailleur :")
print(df_bailleur_raw.columns.tolist())
print()

print("Colonnes - PrioRéno :")
print(df_prioreno_raw.columns.tolist())
# Out:
# Colonnes - bailleur :
# ['Libellé', 'HP1', 'HP2', 'HP3', 'VILLE', 'ADRESSE IKOS RECTIFIE', 'ADRESSE BAN', 'BAN.properties.id', 'RNB']
#
# Colonnes - PrioRéno :
# ['Siren', 'Région', 'Code département', 'Département', 'Adresse principale', 'Commune', 'Code postal', "Nombre d'étages", 'Nombre de logements sociaux', 'Nombre total de logements', 'Identifiant RNB', 'Latitude', 'Longitude']

# %%
# === 1. Normalisation côté bailleur ===
df_bailleur = df_bailleur_raw.rename(columns={"RNB": "ID_RNB"}).copy()

# ID en chaînes propres, sans espaces, et suppression des vides
df_bailleur["ID_RNB"] = (
    df_bailleur["ID_RNB"]
    .astype(str)
    .str.strip()
    .replace({"": pd.NA, "nan": pd.NA})
)
df_bailleur = df_bailleur.dropna(subset=["ID_RNB"])

print("Colonnes bailleur :", df_bailleur.columns.tolist())
print("Nb de lignes bailleur après nettoyage :", len(df_bailleur))
print("Le fichier LMH a pour unité les entrées (col HP3) de bâtiments (col HP2) dans une résidence (col HP1)")

# === 2. Normalisation côté PrioRéno ===
df_prioreno = df_prioreno_raw.rename(columns={"Identifiant RNB": "ID_RNB"}).copy()

# Remplacer les NaN par chaîne vide, trim, puis split sur les espaces
df_prioreno["ID_RNB"] = (
    df_prioreno["ID_RNB"]
    .fillna("")          # NaN -> ""
    .astype(str)
    .str.strip()
)

# On transforme chaque cellule en liste d'IDs (split sur les espaces, y compris multiples)
df_prioreno["ID_RNB"] = df_prioreno["ID_RNB"].str.split()

# On "explose" pour avoir une ligne par ID_RNB
df_prioreno = df_prioreno.explode("ID_RNB")

# Nettoyage : remove vides éventuels
df_prioreno["ID_RNB"] = (
    df_prioreno["ID_RNB"]
    .astype(str)
    .str.strip()
    .replace({"": pd.NA, "nan": pd.NA})
)
df_prioreno = df_prioreno.dropna(subset=["ID_RNB"])

print(" ")
print("Colonnes PrioRéno :", df_prioreno.columns.tolist())
print("Nb de lignes PrioRéno après éclatement/clean :", len(df_prioreno))
# Out:
# Colonnes bailleur : ['Libellé', 'HP1', 'HP2', 'HP3', 'VILLE', 'ADRESSE IKOS RECTIFIE', 'ADRESSE BAN', 'BAN.properties.id', 'ID_RNB']
# Nb de lignes bailleur après nettoyage : 5355
# Le fichier LMH a pour unité les entrées (col HP3) de bâtiments (col HP2) dans une résidence (col HP1)
#
# Colonnes PrioRéno : ['Siren', 'Région', 'Code département', 'Département', 'Adresse principale', 'Commune', 'Code postal', "Nombre d'étages", 'Nombre de logements sociaux', 'Nombre total de logements', 'ID_RNB', 'Latitude', 'Longitude']
# Nb de lignes PrioRéno après éclatement/clean : 2391

# %%
# Combien de lignes LMH contiennent un ID RNB également présent dans PrioRéno ?

# Ensemble des IDs PrioRéno
ids_prioreno = set(df_prioreno["ID_RNB"])

# Sélection des lignes bailleur dont l'ID existe dans PrioRéno
df_bailleur_matched = df_bailleur[df_bailleur["ID_RNB"].isin(ids_prioreno)]



print(f"Nombre de lignes LMH avec un ID RNB présent dans PrioRéno :", len(df_bailleur_matched))
print("Nombre de lignes dans LMH : ", len(df_bailleur))
print("Pourcentage : ", (len(df_bailleur_matched) / len(df_bailleur) * 100 ))
# Out:
# Nombre de lignes LMH avec un ID RNB présent dans PrioRéno : 3246
# Nombre de lignes dans LMH :  5355
# Pourcentage :  60.61624649859944

# %%
# Extrait des lignes qui matchent

df_joint = df_bailleur_matched.merge(
    df_prioreno,
    on="ID_RNB",
    how="left",
    suffixes=("_LMH", "_PR")
)

# Adresse LMH : ADRESSE IKOS RECTIFIE + VILLE
df_joint["ADRESSE_LMH"] = (
    df_joint["ADRESSE IKOS RECTIFIE"].astype(str).str.strip()
)

# Adresse PrioRéno : Adresse principale + CP + Commune
df_joint["ADRESSE_PR"] = (
    df_joint["Adresse principale"].astype(str).str.strip()
)

# =========================
# 4. Extrait des lignes qui matchent
# =========================
extrait = df_joint[[
    "ID_RNB",
    "ADRESSE_LMH",
    "ADRESSE_PR",
]].sample(n=100, random_state=42)

print(extrait.to_string(index=False))
# Out:
#       ID_RNB                                       ADRESSE_LMH                                            ADRESSE_PR
# 4PC5G7KVDB2X                   44  RUE  DU FOUR A CHAUX, LILLE                    44 RUE DU FOUR A CHAUX 59000 LILLE
# XTBD73CZFZRW        102  RUE  DES COULONS PROLONGEE, TOURCOING              102 Rue des Coulons prolongée  TOURCOING
# RGP71DYNHK6B                28  RUE DE L AMIRAL COURBET, LILLE                24 RUE DE L AMIRAL COURBET 59800 LILLE
# 7FH14RCAD82F                            12  RUE CABANIS, LILLE                              0002B RUE CABANIS  LILLE
# RWPHHHTCJ129         57  RUE DES CHERCHEURS, VILLENEUVE D ASCQ          1 RUE DES CHERCHEURS 59650 VILLENEUVE D ASCQ
# 61JPXCKEY8E6                     30  RUE  ROGER SALENGRO, LOOS                      30 RUE ROGER SALENGRO 59120 LOOS
# JN15NA2MA4WX                      152  RUE DU COLLEGE, ROUBAIX                      152 RUE DU COLLEGE 59100 ROUBAIX
# FQT8C8D5MY39                        88  RUE FRAGONARD, ROUBAIX                          161 RUE RUBENS 59100 ROUBAIX
# AQT5ED293DRD                  94  RUE  DE LA TOSSEE, TOURCOING                   92 RUE DE LA TOSSEE 59200 TOURCOING
# PWYAZJZDD9KE                      3  RUE PABLO PICASSO, SECLIN                      1 RUE PABLO PICASSO 59113 SECLIN
# ENR979DSXHVA                     5  RUE DE L AQUITAINE, WAVRIN                        1 RUE D AQUITAINE 59136 WAVRIN
# Y4A2MDPN6ZQY                      231  BD DE FOURMIES, ROUBAIX                 55 RUE LEONARD DE VINCI 59100 ROUBAIX
# H9XH7XSF9FGT                        46  RUE FRAGONARD, ROUBAIX            46 RUE JEAN HONORE FRAGONARD 59100 ROUBAIX
# PWEA6C1Z1518                        84  RUE FRAGONARD, ROUBAIX                  75 AVENUE ALFRED MOTTE 59100 ROUBAIX
# A8QY57SP7SR9                       13  RUE DU COLLEGE, ROUBAIX                       13 RUE DU COLLEGE 59100 ROUBAIX
# 8R21CDVRNX9C            9  RESIDENCE  AMBROISE CROIZAT, SECLIN            10 RESIDENCE AMBROISE CROIZAT 59113 SECLIN
# 4N17CSMK1J13                     112  RUE ETIENNE DOLET, LILLE               0112 RUE ETIENNE DOLET HELLEMMES  LILLE
# E29ZBJGTZXWC                     94B  RUE DE CARIHEM , ROUBAIX                          9001 RUE DE CARIHEM  ROUBAIX
# ARAP6SDDFJWD               95BIS  RUE  ROGER SALENGRO, RONCHIN                     0095B RUE ROGER SALENGRO  RONCHIN
# KJDRT6NRNYRQ                  4  AVENUE ARCH CORDONNIER, LILLE        10 AV DE L ARCHITECTE L CORDONNIER 59800 LILLE
# 5R5WJ6XKREAP                          4 CASSEVILLE RUE CABANIS                0026 CITE CASSEVILLE 23 CABANIS  LILLE
# 1DFN328YCYDD                62  RUE  BRUANT DES ROSEAUX, LILLE                 34 RUE BRUANT DES ROSEAUX 59800 LILLE
# 6W92GWWH2953                         55  RUE VAN DYCK, ROUBAIX                 54 RUE LEONARD DE VINCI 59100 ROUBAIX
# 3PH7G18W7X24                        64  RUE DE LA LYS, ROUBAIX                        64 RUE DE LA LYS 59100 ROUBAIX
# P6HAB98SYF6T                   48  RUE  DE LA LATTE, TOURCOING                    44 RUE DE LA LATTE 59200 TOURCOING
# ZQWEWYTGWGMA                       120  RUE JEAN MACE, ROUBAIX           1 ALLEE PIERRE AUGUSTE RENOIR 59100 ROUBAIX
# F9JF9N486N58                       100  RUE  DU HUTIN, ROUBAIX                        100 RUE DU HUTIN 59100 ROUBAIX
# KF19T7HBBYWX                        5  RUE CH DELESALLE, LILLE                    0011B RUE CHARLES DELESALLE  LILLE
# E8YYWNG8DZXC                       8  RUE ALFRED NAQUET, LILLE                        0002B RUE ALFRED NAQUET  LILLE
# DCVE4PG197BJ                         96  RUE DES ARTS, ROUBAIX                         96 RUE DES ARTS 59100 ROUBAIX
# H87HZZP8XV9A                  6  RUE DU MARECHAL FOCH, WILLEMS                    00013 CLOS DES TISSERANDS  WILLEMS
# FK2WCZCS1VP9                            1  RUE WATTEAU, SECLIN            44 RUE ALEXANDRE DESROUSSEAUX 59113 SECLIN
# FDHAZXZY6YAF                     34  RUE HENRI DUNANT, ROUBAIX                     34 RUE HENRI DUNANT 59100 ROUBAIX
# 87BS37MPV3N3                        37  RUE JEAN MACE, ROUBAIX                        39 RUE JEAN MACE 59100 ROUBAIX
# 6FHQGY3C8M9V            11G  RUE DU TERROIR, VILLENEUVE D ASCQ                0009 RUE DU TERROIR  VILLENEUVE-D-ASCQ
# MDP6DF7H3JT2                      75  RUE  DE PARIS, TOURCOING                       69 RUE DE PARIS 59200 TOURCOING
# E95XNMXR6FKD                   5  ALLEE DES TOURELLES, WILLEMS                  10 ALLEE DES TOURELLES 59780 WILLEMS
# 128HX2WYKB5K                    95  BOULEVARD  D'ALSACE, LILLE                     95 BOULEVARD D ALSACE 59000 LILLE
# E8YYWNG8DZXC                   4BIS  RUE  ALFRED NAQUET, LILLE                        0002B RUE ALFRED NAQUET  LILLE
# KN3NV3WYGDSZ                  27  RUE  DE L'INDUSTRIE, ROUBAIX                   27 RUE DE L INDUSTRIE 59100 ROUBAIX
# H7T96C1ZX9FC                    6  RUE DE LA CONVENTION, LILLE                    6 RUE DE LA CONVENTION 59800 LILLE
# DEXH1E61MQ5M                        31  RUE DE FONTENOY, LILLE                        31 RUE DE FONTENOY 59000 LILLE
# A15764GFJDFR                    1  RUE DES TRAVAILLEURS, LILLE          1 RUE DES TRAVAILLEURS 59260 HELLEMMES LILLE
# 5EV6TDKFZG95                        15  RUE DU CALVAIRE, LILLE                        21 RUE DU CALVAIRE 59800 LILLE
# QKY7BTH826MW 2  ALLEE DE LA CENTIEME MAISON, VILLENEUVE D ASCQ 2 ALLEE DE LA CENTIEME MAISON 59650 VILLENEUVE D ASCQ
# HK1X67R8VWME                             1  RUE COLETTE, LILLE                             1 RUE COLETTE 59000 LILLE
# BQEZ14VERVYE                      63  RUE  DE MOUVAUX, ROUBAIX                       45 RUE DE MOUVAUX 59100 ROUBAIX
# NN2RVT64PYG2                          SQUARE DES MADELONNETTES                     0009 SQ  DES MADELONNETTES  LILLE
# J97J7HMT7QQG                    120  RUE JULES GUESDE, ROUBAIX                    120 RUE JULES GUESDE 59100 ROUBAIX
# ZKM37TSXT9T7                        63  RUE JEAN MACE, ROUBAIX                        59 RUE JEAN MACE 59100 ROUBAIX
# KVP51T5F3JFH                          350  RUE INGRES, ROUBAIX                          350 RUE INGRES 59100 ROUBAIX
# C84S787JQZTY                  300  BOULEVARD DE REIMS, ROUBAIX                            0264 BD  DE REIMS  ROUBAIX
# K5K2KQZW9B9F                      118  RUE DE SOUBISE, ROUBAIX                      118 RUE DE SOUBISE 59100 ROUBAIX

# %%
# Extrait des lignes LMH qui ne matchent pas

df_bailleur_unmatched = df_bailleur[~df_bailleur["ID_RNB"].isin(ids_prioreno)]

# Random sample of 50 (or fewer if not available)
sample_unmatched = df_bailleur_unmatched.sample(
    n=min(50, len(df_bailleur_unmatched)),
    random_state=42
)

# Optional: keep only useful fields
sample_unmatched = sample_unmatched[[
    "ID_RNB",
    "HP1", "HP2", "HP3",
    "ADRESSE IKOS RECTIFIE",
    "VILLE"
]]

print(sample_unmatched.to_string(index=False))
# Out:
#       ID_RNB  HP1  HP2  HP3                                ADRESSE IKOS RECTIFIE                     VILLE
# 3X6BNPKMPCBS T010 0003 0101                   53  RUE PAUL VERSCHAEVE, TOURCOING                 TOURCOING
# S3W9G3GA8X23 1140   01   15                                 15  RUE MONGE, LILLE                     LILLE
# BE55N9S864H5 1450   01   21                        21  RUE PIERRE LEGRAND, LILLE                     LILLE
# G1FMKMZHAH13 T015 0001 0089                   186  RUE ROBERT SCHUMAN, TOURCOING                 TOURCOING
# DZKA2235N2Y8 T009 0001 0003                   6  RUE DU DOCTEUR NAERT, TOURCOING                 TOURCOING
# ZNSFNM7NJE54 R026 0003 0001              1  PLACE JEAN BAPTISTE CLEMENT, ROUBAIX                   ROUBAIX
# 9CV78BWM42ZY T015 0001 0049                     98  RUE MARCEL BEYENS, TOURCOING                 TOURCOING
# YKFK657YX3RT R939 0003 0150                       150  RUE  DU FONTENOY, ROUBAIX                   ROUBAIX
# DTFJW6WVKWZS 3720 0001 0002                         20  RUE  SOUFFLOT, TOURCOING                 TOURCOING
# 9ZT2SCKJPWBB T030 0001 0016                  65  RUE DU MARECHAL JUIN, TOURCOING                 TOURCOING
# DTFJW6WVKWZS 3720 0001 0008                         20  RUE  SOUFFLOT, TOURCOING                 TOURCOING
# RMWFXSVZ1CBF T115 0001 0021                 121  RUE ACHILLE TESTELIN, TOURCOING                 TOURCOING
# HF1WAPC1YD7N 3300 0002 0160                           160  RUE  DE PRAGUE, LILLE                     LILLE
# 2YGF9V12X79G T058 0001 0003                           6  RUE PAUL ESPEELS, RONCQ                     RONCQ
# 5ZFGYPG223MB 1120   01    4                      4  ALLEE DES MARRONNIERS, LILLE                     LILLE
# 51G8CX4TZTNR R013 0005 0123                123  ALLEE CHARDIN, VILLENEUVE D ASCQ         VILLENEUVE D ASCQ
# 29QV1PZTBWSR T115 0001 0003                 117  RUE ACHILLE TESTELIN, TOURCOING                 TOURCOING
# WCRNCV8BAYJY T043 0001 0006                       6  RESIDENCE DU FERRAIN, RONCQ                     RONCQ
# 94PTY6MGCJST T059 0001 0021 21  RESIDENCE LA ROSERAIE, LA CHAPELLE D ARMENTIERES LA CHAPELLE D ARMENTIERES
# J219YCK62ADF T009 0001 0016                          426  RUE COLBERT, TOURCOING                 TOURCOING
# BRHETRY3V8Q4 T071 0001 0024                         28  RUE DE RENNES, TOURCOING                 TOURCOING
# 5KEKXA75PXC2 T038 0002 0180            38  BOULEVARD VAN GOGH, VILLENEUVE D ASCQ         VILLENEUVE D ASCQ
# R1Q71PDT8H63 R007 0006   3E                         3E  RUE DE CARIHEM , ROUBAIX                   ROUBAIX
# WQWTTVBN647B 1250   01   29                       29  RUE  DES CELESTINES, LILLE                     LILLE
# KEHMRX1DAY8M T067 0001 0008                        24  ALLEE DE LINNE, TOURCOING                 TOURCOING
# N6JBCT8KSQ9S 0980   01   17                          17  RUE  DE BAILLEUL, LILLE                     LILLE
# M8JDJN824C5E T108 0001 0237                237  RUE DU GENERAL DROUOT, TOURCOING                 TOURCOING
# 4ST81JA3JVC3 1990  NaN  NaN                     127  RUE  DES BOIS BLANCS, LILLE                     LILLE
# JQ2YBYJTWSQB T016 0010 0318                   143  RUE ROBERT SCHUMAN, TOURCOING                 TOURCOING
# 7WPJZTZA573H 0404   02   46                          46  RUE JULES BRETON, LILLE                     LILLE
# 3NE2AJDZ9BQ8 T016 0003 0071                         32  RUE RENE COTY, TOURCOING                 TOURCOING
# 2C52EW5ZNZDF 6440 0001 0015                        15  CLOS  DE L'ESTREE, SANTES                    SANTES
# 3YSEBPPKX4A5 5190 0003 0003                      9  RUE  DE LA BAILLE, TOURCOING                 TOURCOING
# BVCQFAG5YFQ1 0780   01   11                          11  RUE JULES ROMON, HANTAY                    HANTAY
# XVV451S29646 T075 0011 0011                       34  RUE DE LA VIGNE, TOURCOING                 TOURCOING
# AFC5MPPXECW4 5230 0001 0001                          7  RUE  BAYARD, ARMENTIERES               ARMENTIERES
# 1XVBHSE2KRSR 6810 0001 0001                     42  RUE  ST MICHEL/LOIRE, SALOME                    SALOME
# M7QV3J9NBDAC R036 0001 0019                           19  AVENUE FRASEZ, ROUBAIX                   ROUBAIX
# XQP6ABSPJQBE T016 0006 0174                 16  ALLEE PHILIPPE MATTON, TOURCOING                 TOURCOING
# FB8J2NAQH9TR 0580   02   26                         26  RUE PAUL RAMADIER, LILLE                     LILLE
# FKXHWQAAXJZ3 T012 0001 0038                         38  RUE LAMARTINE, TOURCOING                 TOURCOING
# Y5FF25AHQ1PH T067 0001 0003                        15  ALLEE DE LINNE, TOURCOING                 TOURCOING
# MPAWEA9QTW2V T124 0004 0034         34  ALLEE  LA SAVONNERIE P.TRANOY, TOURCOING                 TOURCOING
# J3XX977N2JFZ R119 0001 0028                        28  RUE SAINT JOSEPH, ROUBAIX                   ROUBAIX
# Z71YDP3KP4NM 4950 0001 0001                         1  QUAI  DE LORIENT, ROUBAIX                   ROUBAIX
# HVKTHC8ZJMBH T016 0002 0021                    23  RUE ROBERT SCHUMAN, TOURCOING                 TOURCOING
# 8QXN7BRYVXHB 0403   01    1                       1  CHEMIN DES BROUTTEUX, LILLE                     LILLE
# BRHETRY3V8Q4 5250 0001 0004                        28  RUE  DE RENNES, TOURCOING                 TOURCOING
# 8ZM53APFEQGN T019 0001 0013                  13  RUE CAPORAL DELROEUX, TOURCOING                 TOURCOING
# C2SW1TDM6BB4 R034 0001 0041                       41  RUE HENRI CARETTE, ROUBAIX                   ROUBAIX

# %%
# Chercher des lignes LMH dans une certaine rue

import pandas as pd

# Liste des sous-chaînes à chercher
required = ["ROLLAND", "20"]  # à adapter

# Colonne d'adresse convertie en string
addr = df_bailleur["ADRESSE IKOS RECTIFIE"].astype(str)

# Masque initial : tout à True
mask = pd.Series(True, index=df_bailleur.index)

# On impose la présence de chaque sous-chaîne
for s in required:
    mask &= addr.str.contains(s, case=False, na=False)

# Filtrage
df_filtered = df_bailleur[mask]

print(df_filtered.to_string(index=False))
# Out:
# Libellé  HP1  HP2  HP3   VILLE           ADRESSE IKOS RECTIFIE                         ADRESSE BAN BAN.properties.id       ID_RNB
# ANSEELE R008 0002 0020 ROUBAIX 20  RUE ROMAIN ROLLAND, ROUBAIX 20 Rue Romain Rolland 59100 Roubaix  59512_4836_00020 YNPDNWWV4Z6G
