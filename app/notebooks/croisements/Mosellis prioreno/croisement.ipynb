# %% [markdown]
# **Questions**
#
# Combien d’ID RNB sont partagés entre le bailleur et PrioRéno ?
# Combien sont juste dans un des deux jeu de données ?
# Est-ce que pour un ID RNB donné le bailleur social et PrioRéno LS parlent du même bâtiment physique.

# %%
import pandas as pd

bailleur_path = 'mosellis.xlsx'
prioreno_path = 'prioreno_mosellis.xlsx'

# %% [markdown]
# ## Colonnes dispo

# %%
df_bailleur_raw = pd.read_excel(bailleur_path)
df_prioreno_raw = pd.read_excel(prioreno_path)

print("Colonnes - bailleur :")
print(df_bailleur_raw.columns.tolist())
print()

print("Colonnes - PrioRéno :")
print(df_prioreno_raw.columns.tolist())
# Out:
# Colonnes - bailleur :
# ['fid', 'cleabs', 'identifiants_rnb', 'ID-Moselis', 'Code programme', 'Code tranche', 'Code ensemble', "Type d'ensemble", 'Adresse', 'Ville', 'Collectif / Individuel', 'Destination', "Bassin d'habitat", 'EPCI']
#
# Colonnes - PrioRéno :
# ['Département', 'Adresse principale', 'Commune', 'Code postal', "Nombre d'étages", 'Nombre de logements sociaux', 'Nombre total de logements', 'Année de construction', 'Identifiant RNB', 'Code ensemble immobilier', 'Latitude', 'Longitude', 'Surface des logements', 'Fiabilité rattachement (Open data/Données indiv. agrégées)', 'Consommation finale globale gaz (Open data/Données indiv. agrégées) (kWh)', 'Consommation finale globale électricité (Open data/Données indiv. agrégées) (kWh)', 'Consommation finale globale total (Open data/Données indiv. agrégées) (kWh)', 'Surface logement HLM électricité  (Open data/Données indiv. agrégées)', 'Fiabilité rattachement (API)', "Chauffage - Type d'équipement", 'Chauffage - Energie principale chauffage', "Chauffage - Type d'installation", 'Chauffage - Couplée avec un équipement secondaire', 'Emissions de CO₂ des consommations électriques (KgCO₂/m²)', 'Emissions de CO₂ des consommations de gaz (KgCO₂/m²)', 'Indicateur de surchauffe des bâtiments (DH)', "Classe de confort d'été", "Fiabilité confort d'été"]

# %%
# === 1. Normalisation côté bailleur ===
df_bailleur = df_bailleur_raw.rename(columns={"identifiants_rnb": "ID_RNB"}).copy()

# ID en chaînes propres, sans espaces, et suppression des vides
df_bailleur["ID_RNB"] = (
    df_bailleur["ID_RNB"]
    .astype(str)
    .str.strip()
    .replace({"": pd.NA, "nan": pd.NA})
)
df_bailleur = df_bailleur.dropna(subset=["ID_RNB"])

print("Colonnes bailleur :", df_bailleur.columns.tolist())
print("Nb de lignes bailleur après nettoyage :", len(df_bailleur))

# === 2. Normalisation côté PrioRéno ===
df_prioreno = df_prioreno_raw.rename(columns={"Identifiant RNB": "ID_RNB"}).copy()

# Remplacer les NaN par chaîne vide, trim, puis split sur les espaces
df_prioreno["ID_RNB"] = (
    df_prioreno["ID_RNB"]
    .fillna("")          # NaN -> ""
    .astype(str)
    .str.strip()
)

# On transforme chaque cellule en liste d'IDs (split sur les espaces, y compris multiples)
df_prioreno["ID_RNB"] = df_prioreno["ID_RNB"].str.split()

# On "explose" pour avoir une ligne par ID_RNB
df_prioreno = df_prioreno.explode("ID_RNB")

# Nettoyage : remove vides éventuels
df_prioreno["ID_RNB"] = (
    df_prioreno["ID_RNB"]
    .astype(str)
    .str.strip()
    .replace({"": pd.NA, "nan": pd.NA})
)
df_prioreno = df_prioreno.dropna(subset=["ID_RNB"])

print(" ")
print("Colonnes PrioRéno :", df_prioreno.columns.tolist())
print("Nb de lignes PrioRéno après éclatement/clean :", len(df_prioreno))
# Out:
# Colonnes bailleur : ['fid', 'cleabs', 'ID_RNB', 'ID-Moselis', 'Code programme', 'Code tranche', 'Code ensemble', "Type d'ensemble", 'Adresse', 'Ville', 'Collectif / Individuel', 'Destination', "Bassin d'habitat", 'EPCI']
# Nb de lignes bailleur après nettoyage : 801
#
# Colonnes PrioRéno : ['Département', 'Adresse principale', 'Commune', 'Code postal', "Nombre d'étages", 'Nombre de logements sociaux', 'Nombre total de logements', 'Année de construction', 'ID_RNB', 'Code ensemble immobilier', 'Latitude', 'Longitude', 'Surface des logements', 'Fiabilité rattachement (Open data/Données indiv. agrégées)', 'Consommation finale globale gaz (Open data/Données indiv. agrégées) (kWh)', 'Consommation finale globale électricité (Open data/Données indiv. agrégées) (kWh)', 'Consommation finale globale total (Open data/Données indiv. agrégées) (kWh)', 'Surface logement HLM électricité  (Open data/Données indiv. agrégées)', 'Fiabilité rattachement (API)', "Chauffage - Type d'équipement", 'Chauffage - Energie principale chauffage', "Chauffage - Type d'installation", 'Chauffage - Couplée avec un équipement secondaire', 'Emissions de CO₂ des consommations électriques (KgCO₂/m²)', 'Emissions de CO₂ des consommations de gaz (KgCO₂/m²)', 'Indicateur de surchauffe des bâtiments (DH)', "Classe de confort d'été", "Fiabilité confort d'été"]
# Nb de lignes PrioRéno après éclatement/clean : 1596

# %%
# Combien de lignes Mosellis contiennent un ID RNB également présent dans PrioRéno ?

# Ensemble des IDs PrioRéno
ids_prioreno = set(df_prioreno["ID_RNB"])

# Sélection des lignes bailleur dont l'ID existe dans PrioRéno
df_bailleur_matched = df_bailleur[df_bailleur["ID_RNB"].isin(ids_prioreno)]



print(f"Nombre de lignes Mosellis avec un ID RNB présent dans PrioRéno :", len(df_bailleur_matched))
print("Nombre de lignes dans Mosellis : ", len(df_bailleur))
print("Pourcentage : ", (len(df_bailleur_matched) / len(df_bailleur) * 100 ))
# Out:
# Nombre de lignes Mosellis avec un ID RNB présent dans PrioRéno : 494
# Nombre de lignes dans Mosellis :  801
# Pourcentage :  61.67290886392009

# %%
# Extrait des lignes qui matchent

df_joint = df_bailleur_matched.merge(
    df_prioreno,
    on="ID_RNB",
    how="left",
    suffixes=("_MOS", "_PR")
)

# Adresse LMH : ADRESSE IKOS RECTIFIE + VILLE
df_joint["ADRESSE_MOS"] = (
    df_joint["Adresse"].astype(str).str.strip()
)

# Adresse PrioRéno : Adresse principale + CP + Commune
df_joint["ADRESSE_PR"] = (
    df_joint["Adresse principale"].astype(str).str.strip()
)

lat = df_joint["Latitude"].astype(str).str.replace(",", ".", regex=False)
lng = df_joint["Longitude"].astype(str).str.replace(",", ".", regex=False)

# Concatenate as "lat,lng"
df_joint["lat_lng"] = lat + "," + lng

# =========================
# 4. Extrait des lignes qui matchent
# =========================
extrait = df_joint[[
    "ID_RNB",
    "ADRESSE_MOS",
    "ADRESSE_PR",
    "lat_lng"
]].sample(n=100, random_state=42)

print(extrait.to_string(index=False))
# Out:
#       ID_RNB                                        ADRESSE_MOS                                            ADRESSE_PR                           lat_lng
# MS5MCYPBJ4VW                  14 RUE GEORGES DUCROCQ 57070 METZ                     10 RUE GEORGES DUCROCQ 57070 METZ 49.1078933662404,6.18749587530735
# W9PF84K5CBJW                      3 LES GERANIUMS 57600 FORBACH                           0001 LES GERANIUMS  FORBACH 49.1775889617142,6.88668975614402
# GQRPJVWHAWF1               50 BOUCLE DU BREUIL 57100 THIONVILLE                  56 BOUCLE DU BREUIL 57100 THIONVILLE 49.3668714178312,6.10821344248647
# VBS8EMZEC73K                       2 RUE DES PINS 57770 MOUSSEY                      1 RUE DES TILLEULS 57770 MOUSSEY 48.6881575677475,6.80217553639129
# 12HCKQEPPJRV                 4 RUE PAUL ALBERT 57100 THIONVILLE                    4 RUE PAUL ALBERT 57100 THIONVILLE 49.3564540554193,6.15627972117682
# CX18Y1MJ2MK2                1 RUE DU CHEVREUIL 57100 THIONVILLE                   7 RUE DU CHEVREUIL 57100 THIONVILLE  49.374284862623,6.15319419249029
# ZYHAAW4ZH8K2                 1 IMPASSE DU JURA 57400 SARREBOURG                      9002 RUE DE MALLERAY  SARREBOURG 48.7300113503145,7.05588148296258
# RGQE9WNJZTA3                 5 C�TE DES VIGNES 57670 ALBESTROFF               5073C LES VIGNES ALBESTROFF  ALBESTROFF 48.9449244227599,6.86645772690712
# 98KJNNZFAA3F               28 BOUCLE DU BREUIL 57100 THIONVILLE                  32 BOUCLE DU BREUIL 57100 THIONVILLE  49.3655239904351,6.1081935809548
# KENKKZC4FTQW             110 AVENUE LONGCHAMP 57380 FAULQUEMONT        1 IMPASSE ANTOINE DE LASALLE 57380 FAULQUEMONT    49.054026741929,6.595724338769
# TRX9B334HMWP                1 IMPASSE DU DAUPHINE 57490 CARLING                   1 IMPASSE DU DAUPHINE 57490 CARLING 49.1712892949186,6.72665804581941
# 8B8ZM1ERPZSX                 358A RUE EDMOND ABOUT 57260 DIEUZE                     358 RUE EDMOND ABOUT 57260 DIEUZE 48.8078529455868,6.71674228516592
# A2CMACEDVNSF                       26 RUE D'OURY 57190 FLORANGE                      2 RUE DE GASCOGNE 57190 FLORANGE 49.3186352494518,6.11850625746714
# H6VNQYJDH14T      20 RUE DU 125E ESCADRON DU TRAIN 57260 DIEUZE         22 RUE DU 125E ESCADRON DU TRAIN 57260 DIEUZE 48.8107094709936,6.72527952173736
# 1C8YWVGPCNV2      C RUE ARTHUR RIMBAUD 57800 FREYMING MERLEBACH                  9003 SQ  RIMBAUD  FREYMING-MERLEBACH 49.1524368526944,6.82499950440148
# 3T7J2V58XNBK                21A RUE DES FRERES 57100 THIONVILLE                    21 RUE DES FRERES 57100 THIONVILLE 49.3495348877264,6.15530803111071
# CMHBM8EVEP2J                      30 RUE DE LA REINE 57640 VIGY                         30 RUE DE LA REINE 57640 VIGY 49.2020230371963,6.29864209509537
# S1DFXTZT3S26         3D IMPASSE DE LA MOSELLE 57320 BOUZONVILLE                  0003D IMP DE LA MOSELLE  BOUZONVILLE 49.2995394035713,6.53343218117878
# H26ZVV4TF9R2                  15 RUE JEAN LURCAT 57800 COCHEREN                     26 RUE JEAN LURCAT 57800 COCHEREN 49.1490101325361,6.84561364114527
# KQ2R3FNT18NC                4 IMPASSE DU PERIGORD 57490 CARLING                     0005 RUE DE LA FRONTIERE  CARLING 49.1714755137089,6.72521754591734
# V63VA5D4EAYC                   2 RUE SAINT JEAN 57360 AMNEVILLE                      10 RUE DE VERDUN 57360 AMNEVILLE 49.2531923307733,6.14137324332665
# ZVXMEA31SWCV                21A RUE DES FRERES 57100 THIONVILLE                    21 RUE DES FRERES 57100 THIONVILLE 49.3495348877264,6.15530803111071
# JAMTFR4KH1Z2        4 IMP ANTOINE DE LASSALLE 57380 FAULQUEMONT        1 IMPASSE ANTOINE DE LASALLE 57380 FAULQUEMONT    49.054026741929,6.595724338769
# PSC6PX62F43X                           5 LES IRIS 57600 FORBACH                                0005 LES IRIS  FORBACH 49.1769859229591,6.88817559717856
# ARREK7C2Y4RZ           9 RUE DU COLONEL MAILLARD 57340 MORHANGE              9 RUE DU COLONEL MAILLARD 57340 MORHANGE 48.9248927740626,6.63448774526775
# 579RVK824CCA  1 RUE DE L'ISLE JOURDAIN 57800 FREYMING MERLEBACH       2 RUE DE ISLE JOURDAIN 57800 FREYMING MERLEBACH 49.1412321630116,6.79560032088998
# VCEF8Z2NXH5T              132 RUE DE MEILBOURG 57100 THIONVILLE                 132 RUE DE MEILBOURG 57100 THIONVILLE 49.3964354944922,6.20040808706969
# 89ZKD9PZSRZX                       34 RUE D'OURY 57190 FLORANGE                      2 RUE DE GASCOGNE 57190 FLORANGE 49.3186352494518,6.11850625746714
# FXRBB2TNF5A1                          1 LES LILAS 57600 FORBACH                               0001 LES LILAS  FORBACH 49.1770112990164,6.88949967681817
# 2NS1ZAFM2VQR             1 IMPASSE DES EGLANTIERS 57600 FORBACH                1 IMPASSE DES EGLANTIERS 57600 FORBACH 49.1979174967932,6.89827432851488
# GMF1KSA8K33N                107 AVENUE ANDRE MALRAUX 57070 METZ                   107 AVENUE ANDRE MALRAUX 57000 METZ  49.099914659869,6.18009678095664
# ERFC8XXST7XB                    1 LES MARGUERITES 57600 FORBACH                         0001 LES MARGUERITES  FORBACH 49.1765798611753,6.89004493314365
# YA3KDMFAXDF5                     2 RUE DE LA GARE 57620 LEMBERG                        2 RUE DE LA GARE 57620 LEMBERG 49.0031423074527,7.38212642304931
# YRQY3PT33JTX          5 IMP J.BAPTISTE LAMOUR 57380 FAULQUEMONT        1 IMPASSE ANTOINE DE LASALLE 57380 FAULQUEMONT    49.054026741929,6.595724338769
# 19G6MVE93GPC            4 RUE DUPONT DES LOGES 57100 THIONVILLE               4 RUE DUPONT DES LOGES 57100 THIONVILLE 49.3442483590297,6.15740449381782
# 2FY3ZHT9WRN8              3 IMPASSE DES MERISIERS 57600 FORBACH                 3 IMPASSE DES MERISIERS 57600 FORBACH  49.1979072543636,6.8966035533335
# Q8D3QZS219F2               1 RUE DE LA PERDRIX 57100 THIONVILLE                  7 RUE DE LA PERDRIX 57100 THIONVILLE 49.3712356209567,6.15357760243162
# Y9JFZVMN732G                1 RUE DU FOU YEGOF 57370 PHALSBOURG      1 RUE DE LA PRINCESSE HENRIETTE 57370 PHALSBOURG 48.7587562253958,7.25514529364189
# HPZW7ZW1YXW5                1 RUE DE L EGLISE 57865 AMANVILLERS                   1 RUE DE L EGLISE 57865 AMANVILLERS 49.1662415999712,6.04251217155006
# FCYZ2A4MDDCA               54 BOUCLE DU BREUIL 57100 THIONVILLE                  62 BOUCLE DU BREUIL 57100 THIONVILLE  49.366985239751,6.10820157991681
# 8R73RSGRT7MQ             149 CHEMIN DU PONT MOREAU 57260 DIEUZE                149 CHEMIN DU PONT MOREAU 57260 DIEUZE 48.8075870466877,6.72064473467022
# ZXS4BTZQP7Q9                  53 RUE DE VERDUN 57100 THIONVILLE                     53 RUE DE VERDUN 57100 THIONVILLE 49.3468473226872,6.15423075920445
# 67XQ3E9A66J9             18A RUE DE PHALSBOURG 57150 CREUTZWALD                   0001A RUE DE PHALSBOURG  CREUTZWALD 49.1991497904254,6.68413017746136
# QB5XDCNYXCPH               80 BOUCLE DU BREUIL 57100 THIONVILLE                  78 BOUCLE DU BREUIL 57100 THIONVILLE 49.3686540784722,6.10826858177539
# MM3C8VNYT56A 35 RUE DES MYRTILLES 57740 LONGEVILLE LES ST AVOLD 35 RUE DES MYRTILLES 57740 LONGEVILLE-LES-SAINT-AVOLD  49.111624144468,6.64132091503382
# JAMTFR4KH1Z2        4 IMP ANTOINE DE LASSALLE 57380 FAULQUEMONT        1 IMPASSE ANTOINE DE LASALLE 57380 FAULQUEMONT    49.054026741929,6.595724338769
# Z69PHV9T8F2J                    7 RUE JEAN JAURES 57700 HAYANGE                       1 RUE JEAN JAURES 57700 HAYANGE 49.3325779150907,6.07652104369184
# 8WQ73MSCNRQN            1 RUE DU GUEOIR 57810 MAIZIERES LES VIC             1 ROUTE DE DIEUZE 57810 MAIZIERES-LES-VIC   48.719631025712,6.7751368958964
# TNY1MK2BD6DN                6 IMPASSE DES SUREAUX 57600 FORBACH                   6 IMPASSE DES SUREAUX 57600 FORBACH 49.1971337650593,6.89537172259297
# RG43AVYMQYTN                1 RUE DU CHEVREUIL 57100 THIONVILLE                   5 RUE DU CHEVREUIL 57100 THIONVILLE 49.3741360346384,6.15316631544811
# 8MNEDYRCVXB3             22 RUE ROBERT SCHUMANN 57360 AMNEVILLE                      10 RUE DE VERDUN 57360 AMNEVILLE 49.2531923307733,6.14137324332665
# 8MD97V4M6657               42 BOUCLE DU BREUIL 57100 THIONVILLE                  44 BOUCLE DU BREUIL 57100 THIONVILLE 49.3660777923056,6.10815653223307
# XNNAQH7JHWV4             2A RUE PIERRE BEREGOVOY 57240 NILVANGE                 2 RUE PIERRE BEREGOVOY 57240 NILVANGE 49.3417155453757,6.04326755962623
# XFPC2XZN18BR            21 RUE JEAN BURGER 57350 STIRING WENDEL               21 RUE JEAN BURGER 57350 STIRING WENDEL 49.2019929498268,6.93591311401855
# N28ZXEW9J8CA          1 IMP SEBASTIEN LECLERC 57380 FAULQUEMONT        1 IMPASSE ANTOINE DE LASALLE 57380 FAULQUEMONT    49.054026741929,6.595724338769
# 995T4Y35THN2                      20B GRAND RUE 57480 WALDWISSE                        0020B GR  GRAND RUE  WALDWISSE  49.412972328413,6.52891721470978
# GM2ESGTFWN8X       1 PLACE CAPITAINE N. SCHNEIDER 57700 HAYANGE               1 PLACE NICOLAS SCHNEIDER 57700 HAYANGE  49.3311263542635,6.0648899227482
# EQEW1QYNF1F1              6 RUE DU BOISMORTIER 57100 THIONVILLE                 6 RUE DE BOISMORTIER 57100 THIONVILLE 49.3661508771376,6.15622913139276
# CCF3DKK3N7YC                      8 RUE DU MOULIN 57300 TREMERY                        10 RUE DU MOULIN 57300 TREMERY 49.2476836645667,6.22169928176126
# 446739RJACVV                     50 RUE DE VILLERS 57120 ROMBAS                        50 RUE DE VILLERS 57120 ROMBAS 49.2468769772792,6.09771852865461
# BZ7XV21GJV3T                         2 RUE DEMOTI 57525 TALANGE                         2 RUE DU DEMOTI 57525 TALANGE 49.2295554780075,6.16830719276023
# 7T7RKV9SYMC2                2 RUE DES MESANGES 57150 CREUTZWALD                   1 RUE DES MESANGES 57150 CREUTZWALD 49.2114684601417,6.71348868241646
# CMHBM8EVEP2J                      30 RUE DE LA REINE 57640 VIGY                         30 RUE DE LA REINE 57640 VIGY 49.2020230371963,6.29864209509537
# 15NR2C1G51Z3                   11 RUE DES MESANGES 57120 ROMBAS                       1 RUE DES MESANGES 57120 ROMBAS 49.2452696150743,6.09078416664316
# C6E9AQ4J5FC1                 46 RUE DE L ARGONNE 57190 FLORANGE                    36 RUE DE L ARGONNE 57190 FLORANGE 49.3221805335127,6.12210012562037
# 3YR542JC89P7                 1 IMPASSE DU JURA 57400 SARREBOURG                    3 IMPASSE DU JURA 57400 SARREBOURG 48.7297850680184,7.05547208236733
# GHHHWR2MTD7Q          28 ROUTE DE LA BRIQUERIE 57100 THIONVILLE             24 ROUTE DE LA BRIQUERIE 57100 THIONVILLE 49.3640655022059,6.15889724462359
# GBAYTKN5EWCY                 1 RUE DU BRUCHGRABEN 57600 FORBACH                    1 RUE DU BRUCHGRABEN 57600 FORBACH 49.1948121027761,6.88099080171519
# PJHT585WN3PJ                   2 RUE CHAMPS ROBERT 57120 ROMBAS                           0001A RUE DES ROSES  ROMBAS 49.2453575552273,6.10347517811975
# E1H222Q5Z8TJ                     14 RUE DU MOULIN 57300 TREMERY                        10 RUE DU MOULIN 57300 TREMERY 49.2476836645667,6.22169928176126
# KQ2R3FNT18NC                4 IMPASSE DU PERIGORD 57490 CARLING                     0005 RUE DE LA FRONTIERE  CARLING 49.1714755137089,6.72521754591734
# 9SM2XQ2P6NB7             45 RUE CHARLES DE VILLERS 57220 BOULAY        45 RUE CHARLES DE VILLERS 57220 BOULAY MOSELLE 49.1807973042378,6.49295380512151
# YWMXRHGV4KRQ       1 SQUARE ST MAURICE 57800 FREYMING MERLEBACH          1 RUE SAINT MAURICE 57800 FREYMING MERLEBACH   49.144440687199,6.7952705066002
# W4MK7DNHHK6K                 . RUE DU BRUCHGRABEN 57600 FORBACH                   11 RUE DU BRUCHGRABEN 57600 FORBACH 49.1945814077295,6.88121773081806
# 4WB93SN8R8D2          8 IMP SEBASTIEN LECLERC 57380 FAULQUEMONT        1 IMPASSE ANTOINE DE LASALLE 57380 FAULQUEMONT    49.054026741929,6.595724338769
# KVVWS5XKTZYZ                     10 RUE DU MOULIN 57300 TREMERY                        10 RUE DU MOULIN 57300 TREMERY 49.2476836645667,6.22169928176126
# H331A7WN3S22               1 IMPASSE DU RENARD 57100 THIONVILLE                     0002 RUE DU CHEVREUIL  THIONVILLE 49.3733347054994,6.15234689883771
# YCCH3ZA5SH81                       31 RUE DU NORD 57600 FORBACH                          17 RUE DU NORD 57600 FORBACH 49.1953162203689,6.89170026796289
# N7ZZ3J3SNFZJ                3 IMPASSE DES SUREAUX 57600 FORBACH                   2 IMPASSE DES SUREAUX 57600 FORBACH 49.1972596710482,6.89581469332723
# M9ZK1JZNYJKM               11 RUE DU CHEVREUIL 57100 THIONVILLE                  11 RUE DU CHEVREUIL 57100 THIONVILLE 49.3744978964528,6.15254182384786
# W5G1S581TGPT               18 BOUCLE DU BREUIL 57100 THIONVILLE                  20 BOUCLE DU BREUIL 57100 THIONVILLE 49.3650760275319,6.10823268236219
# DSRX3XJFYWE6         22 RUE BELLEVUE 57330 VOLMERANGE LES MINES            12 RUE BELLEVUE 57330 VOLMERANGE-LES-MINES 49.4379029330442,6.07963416633913
# YHA3F6DHDHKF                     1 RUE DU SIEDBORN 57220 BOULAY                8 RUE DU SIEDBORN 57220 BOULAY MOSELLE 49.1825162075032,6.49296601993133
# 6P5FHQ1RZ571         7 ALLEE MARGUERITE 57950 MONTIGNY LES METZ                9001 ALL MARGUERITE  MONTIGNY-LES-METZ 49.0888611536839,6.16157027144788
# 5Z73AKHQZG68                      2 RUE DU BREUIL 57525 TALANGE                         2 RUE DU BREUIL 57525 TALANGE 49.2296229920629,6.16908525040347
# VF2MJRPCK9NE                    10 RUE DU SIEDBORN 57220 BOULAY               10 RUE DU SIEDBORN 57220 BOULAY MOSELLE 49.1828722514225,6.49278781637224
# X6VQWEHS769C              10 RUE MAURICE BARRES 57360 AMNEVILLE                      10 RUE DE VERDUN 57360 AMNEVILLE 49.2531923307733,6.14137324332665
# ZNWYGRCZWMH1                 3 RUE DE MONTAUBAN 57360 AMNEVILLE                      10 RUE DE VERDUN 57360 AMNEVILLE 49.2531923307733,6.14137324332665
# Q1W3Z27YDQSV                     7 RUE DU SIEDBORN 57220 BOULAY                4 RUE DU SIEDBORN 57220 BOULAY MOSELLE 49.1827708836126,6.49282097961397
# 7FDVSQ7VKQWP                     5 RUE DES PINSONS 57120 ROMBAS                        5 RUE DES PINSONS 57120 ROMBAS 49.2467489801165,6.08802634395913
# P3K76AZX9JGX        19 RUE DU GENERAL PERSHING 57100 THIONVILLE                      19 RUE PERSHING 57100 THIONVILLE 49.3645849605345,6.16509331556579
# VYWJJ8PJ6D1X                4 IMPASSE DES SUREAUX 57600 FORBACH                   4 IMPASSE DES SUREAUX 57600 FORBACH 49.1976915389774,6.89529204919402
# QSY5MF5P6HMN                    2 LES MARGUERITES 57600 FORBACH                         0002 LES MARGUERITES  FORBACH 49.1762452215513,6.89024559886601
# MFSC9SKMMTXC                3 IMPASSE DE VERDUN 57360 AMNEVILLE                      10 RUE DE VERDUN 57360 AMNEVILLE 49.2531923307733,6.14137324332665
# 4R96YJMN9ZJ2          6 IMP SEBASTIEN LECLERC 57380 FAULQUEMONT        1 IMPASSE ANTOINE DE LASALLE 57380 FAULQUEMONT    49.054026741929,6.595724338769
# APC7KA5W5JW4           19 RUE AMBROISE CROIZAT 57300 HAGONDANGE              11 RUE AMBROISE CROIZAT 57300 HAGONDANGE 49.2462757797678,6.16729510646563
# F5Z8YBRWB2MY                     5 RUE LES ESTAUX 57525 TALANGE                        5 RUE DES ESTAUX 57525 TALANGE 49.2350740880986,6.16513702688545
# 4PXS9MMQKE3S          5 IMP SEBASTIEN LECLERC 57380 FAULQUEMONT        1 IMPASSE ANTOINE DE LASALLE 57380 FAULQUEMONT    49.054026741929,6.595724338769
# NB9N1ZWCP9E1                  10 RUE GEORGES BIZET 57120 ROMBAS                      1 RUE GABRIEL FAURE 57120 ROMBAS 49.2476707706128,6.10420813948447
# E61DQ5XF37R8 11 RUE DU DOCTEUR SCHWEITZER 57130 ARS SUR MOSELLE    11 RUE DU DOCTEUR SCHWEITZER 57130 ARS SUR MOSELLE 49.0761098268217,6.08201410945404
