# %%
filename = 'StockEtablissement_utf8_extrait.csv'

# %%
import os
data_path = os.getcwd()
print(f"{data_path=}")
# Out:
# data_path='/app/notebooks/rapprochements/SIREN'

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
import os
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
# read the excel data
df = pd.read_csv(os.path.join(data_path, filename), sep=",",
                 dtype={"numeroVoieEtablissement": "string", "typeVoieEtablissement": "string", "codePostalEtablissement": "string"})
df['coordonneeLambertAbscisseEtablissement'] = (
    df['coordonneeLambertAbscisseEtablissement']
    .fillna(0)
    .replace('', '0')
    .replace('[ND]', '0')
    .astype(float)
)

df['coordonneeLambertOrdonneeEtablissement'] = (
    df['coordonneeLambertOrdonneeEtablissement']
    .fillna(0)
    .replace('', '0')
    .replace('[ND]', '0')
    .astype(float)
)

# print the df length
print('The length of the dataframe is: ', len(df))
df.head()
df.dtypes
# Out:
# The length of the dataframe is:  1000
# siren                                                      int64
# nic                                                        int64
# siret                                                      int64
# statutDiffusionEtablissement                              object
# dateCreationEtablissement                                 object
# trancheEffectifsEtablissement                             object
# anneeEffectifsEtablissement                              float64
# activitePrincipaleRegistreMetiersEtablissement            object
# dateDernierTraitementEtablissement                        object
# etablissementSiege                                          bool
# nombrePeriodesEtablissement                                int64
# complementAdresseEtablissement                            object
# numeroVoieEtablissement                           string[python]
# indiceRepetitionEtablissement                             object
# dernierNumeroVoieEtablissement                            object
# indiceRepetitionDernierNumeroVoieEtablissement            object
# typeVoieEtablissement                             string[python]
# libelleVoieEtablissement                                  object
# codePostalEtablissement                           string[python]
# libelleCommuneEtablissement                               object
# libelleCommuneEtrangerEtablissement                       object
# distributionSpecialeEtablissement                         object
# codeCommuneEtablissement                                  object
# codeCedexEtablissement                                    object
# libelleCedexEtablissement                                 object
# codePaysEtrangerEtablissement                            float64
# libellePaysEtrangerEtablissement                          object
# identifiantAdresseEtablissement                           object
# coordonneeLambertAbscisseEtablissement                   float64
# coordonneeLambertOrdonneeEtablissement                   float64
# complementAdresse2Etablissement                           object
# numeroVoie2Etablissement                                  object
# indiceRepetition2Etablissement                            object
# typeVoie2Etablissement                                    object
# libelleVoie2Etablissement                                 object
# codePostal2Etablissement                                  object
# libelleCommune2Etablissement                             float64
# libelleCommuneEtranger2Etablissement                     float64
# distributionSpeciale2Etablissement                        object
# codeCommune2Etablissement                                float64
# codeCedex2Etablissement                                   object
# libelleCedex2Etablissement                                object
# codePaysEtranger2Etablissement                           float64
# libellePaysEtranger2Etablissement                        float64
# dateDebut                                                 object
# etatAdministratifEtablissement                            object
# enseigne1Etablissement                                    object
# enseigne2Etablissement                                    object
# enseigne3Etablissement                                    object
# denominationUsuelleEtablissement                          object
# activitePrincipaleEtablissement                           object
# nomenclatureActivitePrincipaleEtablissement               object
# caractereEmployeurEtablissement                           object
# dtype: object

# %%
# display df columns
print(df.columns)
# Out:
# Index(['siren', 'nic', 'siret', 'statutDiffusionEtablissement',
#        'dateCreationEtablissement', 'trancheEffectifsEtablissement',
#        'anneeEffectifsEtablissement',
#        'activitePrincipaleRegistreMetiersEtablissement',
#        'dateDernierTraitementEtablissement', 'etablissementSiege',
#        'nombrePeriodesEtablissement', 'complementAdresseEtablissement',
#        'numeroVoieEtablissement', 'indiceRepetitionEtablissement',
#        'dernierNumeroVoieEtablissement',
#        'indiceRepetitionDernierNumeroVoieEtablissement',
#        'typeVoieEtablissement', 'libelleVoieEtablissement',
#        'codePostalEtablissement', 'libelleCommuneEtablissement',
#        'libelleCommuneEtrangerEtablissement',
#        'distributionSpecialeEtablissement', 'codeCommuneEtablissement',
#        'codeCedexEtablissement', 'libelleCedexEtablissement',
#        'codePaysEtrangerEtablissement', 'libellePaysEtrangerEtablissement',
#        'identifiantAdresseEtablissement',
#        'coordonneeLambertAbscisseEtablissement',
#        'coordonneeLambertOrdonneeEtablissement',
#        'complementAdresse2Etablissement', 'numeroVoie2Etablissement',
#        'indiceRepetition2Etablissement', 'typeVoie2Etablissement',
#        'libelleVoie2Etablissement', 'codePostal2Etablissement',
#        'libelleCommune2Etablissement', 'libelleCommuneEtranger2Etablissement',
#        'distributionSpeciale2Etablissement', 'codeCommune2Etablissement',
#        'codeCedex2Etablissement', 'libelleCedex2Etablissement',
#        'codePaysEtranger2Etablissement', 'libellePaysEtranger2Etablissement',
#        'dateDebut', 'etatAdministratifEtablissement', 'enseigne1Etablissement',
#        'enseigne2Etablissement', 'enseigne3Etablissement',
#        'denominationUsuelleEtablissement', 'activitePrincipaleEtablissement',
#        'nomenclatureActivitePrincipaleEtablissement',
#        'caractereEmployeurEtablissement'],
#       dtype='object')

# %% [markdown]
# # map to inputs

# %%
def should_include_row(df_row_raw):
    return True

filtered_df = df[df.apply(should_include_row, axis=1)]

# %%
print(f"{len(filtered_df)=}")
# Out:
# len(filtered_df)=1000

# %%
from pyproj import Transformer

# Définir les systèmes de coordonnées source (Lambert) et cible (WGS84)
transformer = Transformer.from_crs("EPSG:2154", "EPSG:4326", always_xy=True)

def row_to_input(df_row_raw):
    df_row = dict(df_row_raw)
    x_lambert = df_row["coordonneeLambertAbscisseEtablissement"]
    y_lambert = df_row["coordonneeLambertOrdonneeEtablissement"]
    
    #print(f"{x_lambert=} {y_lambert=}")
    lng, lat = None, None
    if x_lambert != 0 and y_lambert != 0:
        lng, lat = transformer.transform(float(x_lambert), float(y_lambert))
    
    if pd.isna(df_row["numeroVoieEtablissement"]) or df_row["numeroVoieEtablissement"] == "[ND]":
        address = None
    else:
        #print(f"{type(df_row["numeroVoieEtablissement"])=} {type(df_row["typeVoieEtablissement"])=} {type(df_row["libelleVoieEtablissement"])=} {type(df_row["codePostalEtablissement"])=} {type(df["libelleCommuneEtablissement"])=}")
        address = df_row["numeroVoieEtablissement"] + \
        " " + df_row["typeVoieEtablissement"] + " " + df_row["libelleVoieEtablissement"] + \
        ", " + df_row["codePostalEtablissement"] + " " + df_row["libelleCommuneEtablissement"]
    
    if pd.isna(address):
        address = None
        
    return {
        "ext_id" : df_row["siret"],
        "address": address,
        "lat": lat,
        "lng": lng
    }


inputs = list(filtered_df.apply(row_to_input, axis=1))

# %%
import random
sample_inputs = random.sample(inputs, 1000)
sample_inputs
# Out:
# [{'ext_id': 92266293700015, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 93299058300019,
#   'address': '24 RUE MARCEL BOURDARIAS, 94140 ALFORTVILLE',
#   'lat': 48.809013003430074,
#   'lng': 2.421210039924512},
#  {'ext_id': 90267098300029, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 35070653700015, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 32908710000015,
#   'address': '32 RUE WASHINGTON, 75008 PARIS',
#   'lat': 48.87356899999998,
#   'lng': 2.303777},
#  {'ext_id': 32705827700036,
#   'address': "13 CHEMIN DES PRES SECS, 69380 CIVRIEUX-D'AZERGUES",
#   'lat': 45.854496999999995,
#   'lng': 4.700476999999999},
#  {'ext_id': 80297014500032,
#   'address': '14 RUE COPERNIC, 75016 PARIS',
#   'lat': 48.86913399999999,
#   'lng': 2.290244},
#  {'ext_id': 44940258500029,
#   'address': '14 RUE FERMAT, 75014 PARIS 14',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 41067543300016,
#   'address': '102 AVENUE DES CHAMPS ELYSEES, 75008 PARIS',
#   'lat': 48.871833999999986,
#   'lng': 2.3022970000000003},
#  {'ext_id': 71167057000011,
#   'address': '1 RUE DE VERDUN, 02150 SISSONNE',
#   'lat': 49.573419999999984,
#   'lng': 3.891999},
#  {'ext_id': 91352461700010,
#   'address': '1 RUE DU LUXEMBOURG, 44000 NANTES',
#   'lat': 47.21379599999999,
#   'lng': -1.5326509999999984},
#  {'ext_id': 88498356000019,
#   'address': "5 VOIE DE L'EPINE, 51150 JUVIGNY",
#   'lat': 49.015644999999985,
#   'lng': 4.2741169999999995},
#  {'ext_id': 41253086700016,
#   'address': '18 RUE EMMANUEL TROULET, 45130 MEUNG-SUR-LOIRE',
#   'lat': 47.82470799999999,
#   'lng': 1.6955000000000011},
#  {'ext_id': 51295865300010, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 32359318600022,
#   'address': None,
#   'lat': 42.99508499999999,
#   'lng': 1.1446720000000008},
#  {'ext_id': 32716970200013,
#   'address': '5 RUE DU BEFFROI, 11100 NARBONNE',
#   'lat': 43.19040399999998,
#   'lng': 3.006875},
#  {'ext_id': 98029298100019, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 38801173600054,
#   'address': '59 RUE JEAN JAURES, 59263 HOUPLIN-ANCOISNE',
#   'lat': 50.57391199999998,
#   'lng': 2.991512999999999},
#  {'ext_id': 77566214100099,
#   'address': '5 RUE ALBERT CAMUS, 91220 BRETIGNY-SUR-ORGE',
#   'lat': 48.608781,
#   'lng': 2.3167679999999997},
#  {'ext_id': 98530180300013,
#   'address': '5 RUE SAINT EPHREM, 31500 TOULOUSE',
#   'lat': 43.59627804075392,
#   'lng': 1.4645960345521787},
#  {'ext_id': 90280835100016,
#   'address': '13 RUE DU GENERAL BONNAUD, 59200 TOURCOING',
#   'lat': 50.727742,
#   'lng': 3.176567},
#  {'ext_id': 50481899800024,
#   'address': '429 RUE MAOUCROUSET, 84550 MORNAS',
#   'lat': 44.196951999999996,
#   'lng': 4.735891},
#  {'ext_id': 86740426100010,
#   'address': '34 RUE GEN LECLERC, 56410 ETEL',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 43885327700038, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 34848390000018, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 25140225100010, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 30072209700023,
#   'address': '21 QUAI DU PORT FIDELE, 85800 SAINT-GILLES-CROIX-DE-VIE',
#   'lat': 46.69514099999998,
#   'lng': -1.9335959999999976},
#  {'ext_id': 91359299400010,
#   'address': '8 SEN DES LILAS, 94400 VITRY SUR SEINE',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 82467151500024, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 88108394300012,
#   'address': '145 ROUTE DE PARIS, 16160 GOND-PONTOUVRE',
#   'lat': 45.67129599999997,
#   'lng': 0.1734630000000014},
#  {'ext_id': 52864767000025,
#   'address': '7 AVENUE JEAN MOULIN, 11110 COURSAN',
#   'lat': 43.23181999999998,
#   'lng': 3.0595650000000005},
#  {'ext_id': 31733772300041,
#   'address': '80 RUE DE LA GLACIERE, 91230 MONTGERON',
#   'lat': 48.70899599999998,
#   'lng': 2.4385570000000003},
#  {'ext_id': 49281272200014,
#   'address': '13 RUE DU FORT DEBOUT, 59310 NOMAIN',
#   'lat': 50.50733199999998,
#   'lng': 3.243155},
#  {'ext_id': 41164204400027,
#   'address': '155 RUE DU PAS NOTRE-DAME, 37100 TOURS',
#   'lat': 47.41364399999998,
#   'lng': 0.696222000000001},
#  {'ext_id': 67203036800027,
#   'address': '4 AVENUE DU BAS MEUDON, 92130 ISSY-LES-MOULINEAUX',
#   'lat': 48.82217,
#   'lng': 2.244899000000001},
#  {'ext_id': 39764218200018, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 43519630800025,
#   'address': '128 AVENUE PHILIPPE-AUGUSTE, 75011 PARIS',
#   'lat': 48.857888999999986,
#   'lng': 2.3902489999999994},
#  {'ext_id': 41472916000013,
#   'address': '100 RUE PIERRE BROSSOLETTE, 95200 SARCELLES',
#   'lat': 48.99485199999997,
#   'lng': 2.379036},
#  {'ext_id': 50745589700029, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 75055375200031,
#   'address': '23 ALLEE HENRI SOYER, 72100 LE MANS',
#   'lat': 47.98728399999998,
#   'lng': 0.18551500000000118},
#  {'ext_id': 91052218400019,
#   'address': '21 BOULEVARD PASTEUR, 62100 CALAIS',
#   'lat': 50.94681999999998,
#   'lng': 1.854083000000001},
#  {'ext_id': 49389715100012,
#   'address': '5 AVENUE DU LIMOUSIN, 19230 ARNAC-POMPADOUR',
#   'lat': 45.39683799999999,
#   'lng': 1.3839810000000001},
#  {'ext_id': 90302915500020,
#   'address': '43 RUE DES EPINETTES, 75017 PARIS',
#   'lat': 48.89605900000001,
#   'lng': 2.323068000000001},
#  {'ext_id': 48413433300026, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 39448604700019, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 43838046100022,
#   'address': '33 RUE DE L’EGLISE, 41120 MONTHOU-SUR-BIEVRE',
#   'lat': 47.473382,
#   'lng': 1.2974520000000014},
#  {'ext_id': 51075456700020, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 82945310900011,
#   'address': '4 BOULEVARD DE LA SOUFRIERE, 97100 BASSE-TERRE',
#   'lat': 6.0808412395173175,
#   'lng': 2.543291595688917},
#  {'ext_id': 81443470000013,
#   'address': '5 RUE JULES FERRY, 93110 ROSNY-SOUS-BOIS',
#   'lat': 48.873618999999984,
#   'lng': 2.4793180000000006},
#  {'ext_id': 81133613000026,
#   'address': '48 AVENUE DU 8 MAI 1945, 64100 BAYONNE',
#   'lat': 43.46939996726878,
#   'lng': -1.4896820072718955},
#  {'ext_id': 48789870200013,
#   'address': None,
#   'lat': 50.72735999999998,
#   'lng': 2.737933},
#  {'ext_id': 52367574200028,
#   'address': '39 LOTISSEMENT LES EPINETTES, 14230 OSMANVILLE',
#   'lat': 49.33070399999999,
#   'lng': -1.0807879999999985},
#  {'ext_id': 32441928201373,
#   'address': '23 RUE DANJOU, 92100 BOULOGNE BILLANCOURT',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 49537210400010,
#   'address': '46 AV VICTOR HUGO, 29270 CARHAIX-PLOUGUER',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 40975663200017,
#   'address': '1121 ROUTE DE POUILLON, 40180 HEUGAS',
#   'lat': 43.633201999999976,
#   'lng': -1.0829519999999984},
#  {'ext_id': 40844018800014, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 49892417400010,
#   'address': '31 RUE TASTET, 33000 BORDEAUX',
#   'lat': 44.83485199999998,
#   'lng': -0.5826629999999992},
#  {'ext_id': 79483853200040,
#   'address': '21 RUE DU DOCTEUR HENRI ROUSSEL, 97430 LE TAMPON',
#   'lat': 55.75759329291287,
#   'lng': -2.5776168119519682},
#  {'ext_id': 89907669900011,
#   'address': "14 RUE DES ARPENTS ANDIGNE, 49220 LE LION D'ANGERS",
#   'lat': None,
#   'lng': None},
#  {'ext_id': 93273393400016,
#   'address': '9 CHEMIN SAVIT, 31100 TOULOUSE',
#   'lat': 43.58843595975362,
#   'lng': 1.3939250560673955},
#  {'ext_id': 39290757200011,
#   'address': '10 AVENUE LEONARD DE VINCI, 63000 CLERMONT-FERRAND',
#   'lat': 45.764303000000005,
#   'lng': 3.1343000000000005},
#  {'ext_id': 83182238200014,
#   'address': '13 RUE DES VERGERS, 78960 VOISINS-LE-BRETONNEUX',
#   'lat': 48.755825999999985,
#   'lng': 2.058301},
#  {'ext_id': 31053006800033,
#   'address': '18 PL 5 MARTYRS LYCEE BUFFON, 75014 PARIS 14',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 41755833500051, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 88205381200013,
#   'address': '1 IMPASSE DES VIOLETTES, 69330 PUSIGNAN',
#   'lat': 45.75728399999999,
#   'lng': 5.063622999999999},
#  {'ext_id': 35309095400036,
#   'address': '3 AV PAUL VERLAINE, 38000 GRENOBLE',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 48237362800023, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 41213630100014, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 42077283200028, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 41912294000010,
#   'address': '2 RUE DE VERN, 35200 RENNES',
#   'lat': 48.101881999999996,
#   'lng': -1.6602459999999988},
#  {'ext_id': 64288032200085, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 31670341200015, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 34412012600018,
#   'address': '19 RUE LUISANT, 91310 MONTLHERY',
#   'lat': 48.63930599999999,
#   'lng': 2.2691880000000006},
#  {'ext_id': 90307265000018,
#   'address': '7 RUE SAINTE-LUCIE, 51600 JONCHERY-SUR-SUIPPE',
#   'lat': 49.15985299999998,
#   'lng': 4.477423},
#  {'ext_id': 90153132700012,
#   'address': '22 RUE TRIPON, 66320 VINCA',
#   'lat': 42.64446299999997,
#   'lng': 2.527346000000001},
#  {'ext_id': 83373399100016,
#   'address': '50 RUE DE LA BIDASSOA, 75020 PARIS',
#   'lat': 48.86750299999998,
#   'lng': 2.3914739999999997},
#  {'ext_id': 44489099000013,
#   'address': '23 RUE DE SEZE, 69006 LYON',
#   'lat': 45.76812599999999,
#   'lng': 4.845597999999999},
#  {'ext_id': 35300220700028,
#   'address': '8 RUE DES FRANCS BOURGEOIS, 67000 STRASBOURG',
#   'lat': 48.58153599999998,
#   'lng': 7.746130999999998},
#  {'ext_id': 53048504400016,
#   'address': '15 AVENUE DE SCHWARZENBEK, 07200 AUBENAS',
#   'lat': 44.620622000000004,
#   'lng': 4.379886},
#  {'ext_id': 91336758700023, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 30460318600046,
#   'address': '176 RUE DU TEMPLE, 75003 PARIS',
#   'lat': 48.86678099999998,
#   'lng': 2.362492},
#  {'ext_id': 66204737200328,
#   'address': '11 RUE EMMANUEL ARAGO, 93130 NOISY-LE-SEC',
#   'lat': 48.898406999999985,
#   'lng': 2.462684},
#  {'ext_id': 80813012400015,
#   'address': '19 ROUTE NATIONALE, 59144 JENLAIN',
#   'lat': 50.30477599999999,
#   'lng': 3.628934},
#  {'ext_id': 88963901900021, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 50515250400021, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 85286857900016,
#   'address': None,
#   'lat': 45.747325999999994,
#   'lng': 4.690555999999998},
#  {'ext_id': 52276703700016,
#   'address': '16 AVENUE DES CHATEAUPIEDS, 92500 RUEIL-MALMAISON',
#   'lat': 48.881019999999985,
#   'lng': 2.174713000000001},
#  {'ext_id': 37898506300049,
#   'address': '40 RUE DU BASSIN, 34400 SAINT-SERIES',
#   'lat': 43.73187599999998,
#   'lng': 4.104869},
#  {'ext_id': 50870103400011,
#   'address': None,
#   'lat': 47.547021,
#   'lng': 5.6943519999999985},
#  {'ext_id': 5720084200011,
#   'address': '38 BD DU MARECHAL FOCH, 49000 ANGERS',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 49811975900013,
#   'address': '58 RUE DE LA MAIRIE, 44119 TREILLIERES',
#   'lat': 47.33006899999999,
#   'lng': -1.6226939999999983},
#  {'ext_id': 69654013700010,
#   'address': None,
#   'lat': 48.253723999999984,
#   'lng': 0.04608600000000147},
#  {'ext_id': 30623992200025,
#   'address': '3 PLACE WILSON, 83390 PIERREFEU-DU-VAR',
#   'lat': 43.226964999999986,
#   'lng': 6.143070999999998},
#  {'ext_id': 41029548900018, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 90295688700019,
#   'address': None,
#   'lat': 44.74087399999998,
#   'lng': 5.038621999999999},
#  {'ext_id': 43197496300198,
#   'address': '3 RUE COLBERT, 29200 BREST',
#   'lat': 48.38827299999999,
#   'lng': -4.485762999999995},
#  {'ext_id': 33454898900030,
#   'address': '7 RUE DE QUEBEC, 80090 AMIENS',
#   'lat': 49.87051299999998,
#   'lng': 2.321634000000001},
#  {'ext_id': 45325586100016,
#   'address': '244 AV PAULINE DE SIMIANE, 13320 BOUC-BEL-AIR',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 41012985200019, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 85120636700019, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 39214302000015,
#   'address': None,
#   'lat': 47.72435800000001,
#   'lng': -2.118045999999998},
#  {'ext_id': 82497733400013,
#   'address': '5 PLACE SAINT PONS, 30400 VILLENEUVE-LES-AVIGNON',
#   'lat': 43.963461999999986,
#   'lng': 4.797526},
#  {'ext_id': 44413829100034,
#   'address': '2 PLACE SAINT-PIERRE, 16000 ANGOULEME',
#   'lat': 45.64921899999998,
#   'lng': 0.15099800000000044},
#  {'ext_id': 49824435900010,
#   'address': '6 AVENUE JEAN JAURES, 77360 VAIRES-SUR-MARNE',
#   'lat': 48.87452299999999,
#   'lng': 2.638542},
#  {'ext_id': 39263030700016,
#   'address': '36 RUE PAUL VERLAINE, 69100 VILLEURBANNE',
#   'lat': 45.76495400000001,
#   'lng': 4.880292},
#  {'ext_id': 42979495100021, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 31734877900032,
#   'address': '18 RUE PAUL CEZANNE, 69330 MEYZIEU',
#   'lat': 45.76692299999997,
#   'lng': 4.986532999999999},
#  {'ext_id': 38841569700027,
#   'address': '481 CHEMIN DES CHATAIGNERAIES, 47500 BLANQUEFORT-SUR-BRIOLANCE',
#   'lat': 44.60931400569929,
#   'lng': 0.9346160293583751},
#  {'ext_id': 83103372500019, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 88855829300013,
#   'address': '3 RUE DU CHATEAU, 67980 HANGENBIETEN',
#   'lat': 48.55967999999999,
#   'lng': 7.611201999999999},
#  {'ext_id': 93388168200019, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 43307733600025, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 94471688500016,
#   'address': '3 PLACE DE LA BICHE, 77220 GRETZ-ARMAINVILLIERS',
#   'lat': 48.73629101694086,
#   'lng': 2.7368980649823067},
#  {'ext_id': 82988412100015,
#   'address': '194 AVENUE JEAN JAURES, 75019 PARIS',
#   'lat': 48.88819799999998,
#   'lng': 2.391497000000001},
#  {'ext_id': 32249010300015,
#   'address': '33 ALL PAMPARA, 40100 DAX',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 92511856400010, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 89812809500012,
#   'address': '2 PLACE DE LA BOULAIE, 94470 BOISSY-SAINT-LEGER',
#   'lat': 48.75368299999999,
#   'lng': 2.499747000000001},
#  {'ext_id': 39379696600132,
#   'address': '13 CHEMIN DES FRENES, 17100 SAINTES',
#   'lat': 45.74019599999998,
#   'lng': -0.6427669999999988},
#  {'ext_id': 53397074500071,
#   'address': '27 AVENUE DES RENARDIERES, 85000 LA ROCHE-SUR-YON',
#   'lat': 46.65326299999998,
#   'lng': -1.4344369999999984},
#  {'ext_id': 91923883200019,
#   'address': '6 TRAVERSE DU COMMANDANT, 13014 MARSEILLE',
#   'lat': 43.31694399999999,
#   'lng': 5.387384},
#  {'ext_id': 41926765300022,
#   'address': '89 RUE LA FAYETTE, 75009 PARIS',
#   'lat': 48.877166999999986,
#   'lng': 2.3484439999999998},
#  {'ext_id': 40915859900012,
#   'address': '40 RUE ST JOSEPH, 85600 BOUFFERE',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 33844205600028,
#   'address': '81 ROUTE DE PARIS, 44300 NANTES',
#   'lat': 47.25116799999999,
#   'lng': -1.5179979999999973},
#  {'ext_id': 34194860200014,
#   'address': None,
#   'lat': 47.03580999999996,
#   'lng': 5.539377},
#  {'ext_id': '40150132500021', 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 41773410000015,
#   'address': '14 RUE DE LA REPUBLIQUE, 45300 LE MALESHERBOIS',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 51344183200013,
#   'address': '10 RUE DU BOIS, 78320 LA VERRIERE',
#   'lat': 48.758008999999994,
#   'lng': 1.9583430000000006},
#  {'ext_id': 80216453300027,
#   'address': '26 RUE DU FAUBOURG DU TEMPLE, 75011 PARIS',
#   'lat': 48.86850799999999,
#   'lng': 2.3667029999999993},
#  {'ext_id': 98269489500011, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 66588057100013, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 78305619500010, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 85057782600017,
#   'address': '16 RUE FONTAINE-SAINT-MARTIN, 66000 PERPIGNAN',
#   'lat': 42.69340899999999,
#   'lng': 2.8858309999999996},
#  {'ext_id': 91308493500018,
#   'address': '6 RUE IDRAC, 31000 TOULOUSE',
#   'lat': 43.601014,
#   'lng': 1.452936},
#  {'ext_id': 80209891300014,
#   'address': '1849 ROUTE DU GARGALON, 83600 FREJUS',
#   'lat': 43.472632,
#   'lng': 6.745709999999999},
#  {'ext_id': 80760575300019,
#   'address': '10 RUE ADAM DE CRAPONNE, 34000 MONTPELLIER',
#   'lat': 43.606895999999985,
#   'lng': 3.868761},
#  {'ext_id': 49321051200015,
#   'address': '9 ALLEE DES TOURTERELLES, 47300 BIAS',
#   'lat': 44.41895499999999,
#   'lng': 0.6880190000000008},
#  {'ext_id': 75307237000012,
#   'address': '17 RUE DU CHATEAU, 34560 VILLEVEYRAC',
#   'lat': 43.5002,
#   'lng': 3.6081509999999994},
#  {'ext_id': 82195107600016,
#   'address': '190 RUE DU STADE, 02200 VENIZEL',
#   'lat': 49.36612999999999,
#   'lng': 3.3985779999999997},
#  {'ext_id': 38395868300021,
#   'address': '29 AV DE LA PLAGE, 33740 ARES',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 42432612200035,
#   'address': '8 RUE DETHAN, 78710 ROSNY-SUR-SEINE',
#   'lat': 48.99943899999998,
#   'lng': 1.6355420000000003},
#  {'ext_id': 30887794300412,
#   'address': '1 RUE DE LA SEINE, 35470 BAIN-DE-BRETAGNE',
#   'lat': 47.85227899999999,
#   'lng': -1.6900049999999982},
#  {'ext_id': 41472354400030, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 47862350700025,
#   'address': '13 RUE DU 8 MAI 1945, 74460 MARNAZ',
#   'lat': 46.06064299999998,
#   'lng': 6.529780999999999},
#  {'ext_id': 80766190500016, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 47812926500011,
#   'address': None,
#   'lat': 47.870511999999984,
#   'lng': -4.063500999999996},
#  {'ext_id': 94992730500019, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 30178836000016, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 94398568900018,
#   'address': '1 RUE FRANCOISE PELLEHETTE, 80330 LONGUEAU',
#   'lat': 49.87247602005369,
#   'lng': 2.3590640144895976},
#  {'ext_id': 45180573300024,
#   'address': '6 PLACE DU THEATRE, 26200 MONTELIMAR',
#   'lat': 44.55669999999998,
#   'lng': 4.747347999999999},
#  {'ext_id': 98456182900016,
#   'address': '61 RUE DE LYON, 75012 PARIS',
#   'lat': 48.85055199999999,
#   'lng': 2.3701359999999996},
#  {'ext_id': 41906835800011,
#   'address': '11 RUE DU CHENE, 67100 STRASBOURG',
#   'lat': 48.56872699999998,
#   'lng': 7.749789999999995},
#  {'ext_id': 94174809700016,
#   'address': '141 ROUTE DU LEMAN, 74160 ARCHAMPS',
#   'lat': 46.13645999272109,
#   'lng': 6.130845010189918},
#  {'ext_id': 48237305700017,
#   'address': '824 AVENUE GENERAL DELESTRAINT, 38560 JARRIE',
#   'lat': 45.10044199999999,
#   'lng': 5.749795999999998},
#  {'ext_id': 98364947600014, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 49061269400011,
#   'address': '470 ROUTE DES TILLEULS, 80700 ROYE',
#   'lat': 49.68671396038061,
#   'lng': 2.7841899947195077},
#  {'ext_id': 81819888900011, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 51003400200012, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 91003293700013,
#   'address': '34 BOULEVARD DES ITALIENS, 75009 PARIS',
#   'lat': 48.87130699999999,
#   'lng': 2.3351139999999995},
#  {'ext_id': 89994582800015,
#   'address': '143 RUE DES BOURGUIGNONS, 92270 BOIS-COLOMBES',
#   'lat': 48.91886299999999,
#   'lng': 2.280257},
#  {'ext_id': 91783762700012,
#   'address': '85 IMPASSE DES ROSIERS, 76160 SAINT-MARTIN-DU-VIVIER',
#   'lat': 49.470000000000006,
#   'lng': 1.1627900000000009},
#  {'ext_id': 75337610200038, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 31381151501746,
#   'address': '34 AVENUE DU GENDARME CASTERMANT, 77500 CHELLES',
#   'lat': 48.878012999999974,
#   'lng': 2.6007880000000005},
#  {'ext_id': 30584975400034,
#   'address': '10 RUE PIERRE BENOIT, 31400 TOULOUSE',
#   'lat': 43.58678399999999,
#   'lng': 1.4670380000000005},
#  {'ext_id': 34142550200018,
#   'address': '21 RUE DE TOURTILLE, 75020 PARIS',
#   'lat': 48.87125199999999,
#   'lng': 2.381203},
#  {'ext_id': 42176662700028,
#   'address': '1 SQUARE JEAN HEURTIN, 44000 NANTES',
#   'lat': 47.21489899999998,
#   'lng': -1.5444299999999973},
#  {'ext_id': 79817453800016,
#   'address': '146 AVENUE BUCARIN, 83140 SIX-FOURS-LES-PLAGES',
#   'lat': 43.10359099999998,
#   'lng': 5.822146999999999},
#  {'ext_id': 88097521400011,
#   'address': '57 RUE HONNORAT, 13003 MARSEILLE',
#   'lat': 43.30515999999998,
#   'lng': 5.382914999999999},
#  {'ext_id': 38492259700016,
#   'address': "64 AVENUE DE L'ANCYSE, 30200 BAGNOLS-SUR-CEZE",
#   'lat': 44.16049,
#   'lng': 4.608064},
#  {'ext_id': 42307349300011,
#   'address': '7 RUE DE LA GARE, 60420 MAIGNELAY-MONTIGNY',
#   'lat': 49.55016699999998,
#   'lng': 2.514664},
#  {'ext_id': 82058512300046,
#   'address': '253 BOULEVARD DE LEEDS, 59777 LILLE',
#   'lat': 50.64056199999998,
#   'lng': 3.0750090000000005},
#  {'ext_id': 71204193800010,
#   'address': '79 RUE VOLTAIRE, 92300 LEVALLOIS-PERRET',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 48994353000050,
#   'address': '47 BOULEVARD EMILE ZOLA, 84200 CARPENTRAS',
#   'lat': 44.05168699999998,
#   'lng': 5.04998},
#  {'ext_id': 34028015500029, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 44896941000027,
#   'address': '27 RUE GEILER, 67000 STRASBOURG',
#   'lat': 48.586624999999984,
#   'lng': 7.768894999999998},
#  {'ext_id': 44237802200051,
#   'address': '72 RUE DE LA REPUBLIQUE, 30160 BESSEGES',
#   'lat': 44.290397984087384,
#   'lng': 4.10108897075455},
#  {'ext_id': 78890524800019,
#   'address': '134 BOULEVARD DES LIBERATEURS, 13012 MARSEILLE',
#   'lat': 43.301984999999995,
#   'lng': 5.457146999999998},
#  {'ext_id': 90889603800019,
#   'address': '58 RUE SAINT-BERNARD, 57000 METZ',
#   'lat': 49.095885999999986,
#   'lng': 6.172632999999998},
#  {'ext_id': 95114639800015,
#   'address': None,
#   'lat': 43.278884,
#   'lng': 3.2843900000000006},
#  {'ext_id': 82126041100011,
#   'address': '45 RUE BOURSAULT, 75017 PARIS 17',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 49450273500025,
#   'address': '51 RUE LAVOISIER, 79300 BRESSUIRE',
#   'lat': 46.847965999999985,
#   'lng': -0.4696699999999978},
#  {'ext_id': 30664619100016,
#   'address': None,
#   'lat': 45.79755899999999,
#   'lng': 3.248157999999999},
#  {'ext_id': 85123099500017,
#   'address': '16 RUE SISTERON, 38170 SEYSSINET-PARISET',
#   'lat': 45.17717699999999,
#   'lng': 5.697578999999998},
#  {'ext_id': 80356741100019,
#   'address': '8 PLACE JEAN JAURES, 37000 TOURS',
#   'lat': 47.38970499999999,
#   'lng': 0.689496000000001},
#  {'ext_id': 31394082700014,
#   'address': None,
#   'lat': 4.994418471005543,
#   'lng': 3.0499744416718984},
#  {'ext_id': 52963036000012,
#   'address': '8 CHEMIN BRAS DE FER, 97441 SAINTE-SUZANNE',
#   'lat': 56.07330566788328,
#   'lng': -2.4679720463406047},
#  {'ext_id': 98390889800015, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 80087119600013,
#   'address': '3 RUE LE MOULIN, 33920 SAINT-SAVIN',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 88397276200057,
#   'address': '4 RUE FREDERIC CHOPIN, 35530 NOYAL-SUR-VILAINE',
#   'lat': 48.117513999999986,
#   'lng': -1.5207339999999985},
#  {'ext_id': 93916733400019, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 51945441700022,
#   'address': '1 RUE DE BOURSONNE, 27700 HENNEZIS',
#   'lat': 49.196978999999985,
#   'lng': 1.465535000000001},
#  {'ext_id': 66198045800029,
#   'address': '16 RUE DE STRASBOURG, 24000 PERIGUEUX',
#   'lat': 45.182970999999995,
#   'lng': 0.7154430000000012},
#  {'ext_id': 42851221400019,
#   'address': '72 AVENUE ROGER SALENGRO, 92290 CHATENAY-MALABRY',
#   'lat': 48.77158799999999,
#   'lng': 2.2746979999999994},
#  {'ext_id': 21740012600041,
#   'address': '14 RUE DE L’ANNEXION, 74100 ANNEMASSE',
#   'lat': 46.18574599999999,
#   'lng': 6.239507999999998},
#  {'ext_id': 41320652500011,
#   'address': '5 AVENUE MARECHAL JOFFRE, 66620 BROUILLA',
#   'lat': 42.56663699999998,
#   'lng': 2.9043659999999996},
#  {'ext_id': 35296090000038, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 49840472200015,
#   'address': '4 CHE DU TAMARIS, 84000 AVIGNON',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 38263764300026,
#   'address': '23 BOULEVARD DOCTEUR PONTIER, 81300 GRAULHET',
#   'lat': 43.77163399999998,
#   'lng': 1.993745},
#  {'ext_id': 82262349200011,
#   'address': '22 CHEMIN DE L’EAU, 13550 NOVES',
#   'lat': 43.87473499999998,
#   'lng': 4.900947999999999},
#  {'ext_id': 85102779700014,
#   'address': '3 RUE DES FRERES LUMIERE, 94510 LA QUEUE-EN-BRIE',
#   'lat': 48.78020799999999,
#   'lng': 2.573506000000001},
#  {'ext_id': 47913327400015,
#   'address': '2 RUE DU PROFESSEUR CLERC, 62230 OUTREAU',
#   'lat': 50.701983999999996,
#   'lng': 1.5890720000000012},
#  {'ext_id': 84285968800017,
#   'address': '2 RUE DU CIMETIERE SAINT-RIEUL, 60300 SENLIS',
#   'lat': 49.20779499999998,
#   'lng': 2.585915},
#  {'ext_id': 39006246100020,
#   'address': '4 RUE ANDRE GIDE, 22000 SAINT-BRIEUC',
#   'lat': 48.503745999999985,
#   'lng': -2.7687179999999985},
#  {'ext_id': 82087538300011, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 32776063300013,
#   'address': '89 RUE DUHESME, 75018 PARIS',
#   'lat': 48.89450199999999,
#   'lng': 2.3441650000000003},
#  {'ext_id': 95405501800012,
#   'address': '233 CHEMIN DU BEMONT, 38760 SAINT-PAUL-DE-VARCES',
#   'lat': 45.06596599999999,
#   'lng': 5.642128999999999},
#  {'ext_id': 41868783600019,
#   'address': "7 RUE YVES DECUGIS, 59650 VILLENEUVE-D'ASCQ",
#   'lat': 50.62263999999999,
#   'lng': 3.1461279999999996},
#  {'ext_id': 41755349200055,
#   'address': None,
#   'lat': 47.157138999999965,
#   'lng': 5.788679},
#  {'ext_id': 45313158300016,
#   'address': '2 AVENUE FRANCOIS BOTTAU, 06000 NICE',
#   'lat': 43.71577099999999,
#   'lng': 7.254871999999998},
#  {'ext_id': 48440604600017,
#   'address': '24 RUE NEUVE, 66160 LE BOULOU',
#   'lat': 42.524969999999975,
#   'lng': 2.83526},
#  {'ext_id': 92243291900012,
#   'address': '5 RUE CAMILLE DESMOULINS, 92300 LEVALLOIS-PERRET',
#   'lat': 48.888750999999985,
#   'lng': 2.2844480000000007},
#  {'ext_id': 98283752800016, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 35262367200016, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 88201036600012, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 80923768800019,
#   'address': '5 RUE LAPEYROUSE, 31000 TOULOUSE',
#   'lat': 43.604283999999986,
#   'lng': 1.4464430000000006},
#  {'ext_id': 82890873100064, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 82882748500016,
#   'address': '103 BOULEVARD MACDONALD, 75019 PARIS',
#   'lat': 48.898344,
#   'lng': 2.3845370000000004},
#  {'ext_id': 82894161700023,
#   'address': '71 RUE ETIENNE DOLET, 94140 ALFORTVILLE',
#   'lat': 48.79327699999998,
#   'lng': 2.425639999999999},
#  {'ext_id': 88285823600012,
#   'address': '458 AVENUE DE LA GARE, 34130 VALERGUES',
#   'lat': 43.67159399999998,
#   'lng': 4.060287},
#  {'ext_id': 34930264600014, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 83438399400011,
#   'address': '20 AVENUE DE LA GARE, 29100 DOUARNENEZ',
#   'lat': 48.09537999999998,
#   'lng': -4.343445999999997},
#  {'ext_id': 79289014700012,
#   'address': '27 RUE DE LA MEILLADE, 34150 MONTPEYROUX',
#   'lat': 43.700181999999984,
#   'lng': 3.498623},
#  {'ext_id': 67070613400020,
#   'address': '50 AVENUE ANTOINE DE SAINT EXUPERY, 31400 TOULOUSE',
#   'lat': 43.585961,
#   'lng': 1.464746000000001},
#  {'ext_id': 44791666900024,
#   'address': '81 RUE SAINT-LAZARE, 75009 PARIS',
#   'lat': 48.87592299999998,
#   'lng': 2.3303750000000005},
#  {'ext_id': 41798400200028,
#   'address': '2255 RUE DU SINGE ROUGE, 97355 MACOURIA',
#   'lat': -2.323065995665899,
#   'lng': 0.5355783753237318},
#  {'ext_id': 82790574600018,
#   'address': '25 AVENUE DU GENERAL DE GAULLE, 13360 ROQUEVAIRE',
#   'lat': 43.327248000000004,
#   'lng': 5.597241999999999},
#  {'ext_id': 20001766300010,
#   'address': '20 AVENUE DU MARECHAL LECLERC DE HAUTECLOCQUE, 82400 VALENCE',
#   'lat': 44.11363999999998,
#   'lng': 0.8952470000000013},
#  {'ext_id': 84331056600016, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 88370492600012,
#   'address': '1 CHEMIN DE LA SOYEE, 71380 ALLERIOT',
#   'lat': 46.79672799999999,
#   'lng': 4.944331},
#  {'ext_id': 58980468100015,
#   'address': '33 RUE DU PRESIDENT WILSON, 78230 LE PECQ',
#   'lat': 48.894159999999985,
#   'lng': 2.1125779999999996},
#  {'ext_id': 32648528100017,
#   'address': None,
#   'lat': 45.55305599999999,
#   'lng': 1.7579130000000007},
#  {'ext_id': 38296124100017,
#   'address': '77 RUE DE LA REPUBLIQUE, 93200 SAINT-DENIS',
#   'lat': 48.936740999999984,
#   'lng': 2.3521650000000003},
#  {'ext_id': 29620338300017, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 48184833100015,
#   'address': None,
#   'lat': 46.098987999999984,
#   'lng': 5.1291319999999985},
#  {'ext_id': 85252562500012,
#   'address': '4 RUE PEYPAGAN, 13400 AUBAGNE',
#   'lat': 43.291921999999985,
#   'lng': 5.568217999999999},
#  {'ext_id': 35600074506417,
#   'address': '1 RUE LOUIS JOUVET, 87300 BELLAC',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 31244111600018,
#   'address': None,
#   'lat': 6.241322768454496,
#   'lng': 2.630488478234476},
#  {'ext_id': 85199757700032, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 91225806800010,
#   'address': '1 AVENUE DU GENERAL DE GAULLE, 67800 HŒNHEIM',
#   'lat': 48.61866199999998,
#   'lng': 7.765299999999999},
#  {'ext_id': 88090061800021, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 79285328500023,
#   'address': '87 BOULEVARD ROUGE, 97160 LE MOULE',
#   'lat': 6.354289593964849,
#   'lng': 2.8315885785239496},
#  {'ext_id': 89253074200014, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 40845683800023,
#   'address': '13 RUE DE SAINT-SIMON, 75007 PARIS',
#   'lat': 48.85599499999999,
#   'lng': 2.3237980000000005},
#  {'ext_id': 80057366900028,
#   'address': '63 RUE ANDRE DESSAUX, 45400 FLEURY-LES-AUBRAIS',
#   'lat': 47.92973499999999,
#   'lng': 1.8971660000000001},
#  {'ext_id': 79837293400017,
#   'address': None,
#   'lat': 43.675795,
#   'lng': 3.475316},
#  {'ext_id': 79519815900019,
#   'address': '31 RUE AUGUSTE RATEAU, 17100 SAINTES',
#   'lat': 45.74690499999998,
#   'lng': -0.610826999999999},
#  {'ext_id': 83527870600014,
#   'address': None,
#   'lat': 47.59911799999999,
#   'lng': -1.9367769999999978},
#  {'ext_id': 91849376800017,
#   'address': '77 BOULEVARD MARCEL PAUL, 44800 SAINT-HERBLAIN',
#   'lat': 47.244458999999985,
#   'lng': -1.6184149999999988},
#  {'ext_id': 95351803200016,
#   'address': '3 RUE VOLTAIRE, 92300 LEVALLOIS-PERRET',
#   'lat': 48.89045499999999,
#   'lng': 2.279992000000001},
#  {'ext_id': 35307924700022, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 87794526100015,
#   'address': '12 RUE DU TILLEUL, 19170 TARNAC',
#   'lat': 45.681088999999986,
#   'lng': 1.947416},
#  {'ext_id': 44504486000010,
#   'address': '15 RUE DE DUBLIN, 59760 GRANDE-SYNTHE',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 81530622000022,
#   'address': '10 ALLEE DES GENETS, 38100 GRENOBLE',
#   'lat': 45.161146999999985,
#   'lng': 5.734683999999999},
#  {'ext_id': 21210113300016, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 90154226600027,
#   'address': '32 RUE FAIDHERBE, 93700 DRANCY',
#   'lat': 48.922559,
#   'lng': 2.433723},
#  {'ext_id': 41529652400010,
#   'address': '6 RUE PICOT, 83000 TOULON',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 30813605000033,
#   'address': '3 RUE DES BUISSONS, 71530 CRISSEY',
#   'lat': 46.81634899999999,
#   'lng': 4.8768699999999985},
#  {'ext_id': 80526378700022,
#   'address': '251 RUE LOUIS ET AUGUSTE LUMIERE, 01630 SAINT-GENIS-POUILLY',
#   'lat': 46.234954999999985,
#   'lng': 6.0254199999999996},
#  {'ext_id': 75061474500024,
#   'address': "23 CHEMIN DE L'OUM, 65200 CIEUTAT",
#   'lat': 43.12065699999999,
#   'lng': 0.21438700000000072},
#  {'ext_id': 78091596300034,
#   'address': '213 RUE DES MIMOSAS, 50000 SAINT-LO',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 49441618300015,
#   'address': '28 RUE DE CHATEAUDUN, 75009 PARIS',
#   'lat': 48.87615,
#   'lng': 2.337389},
#  {'ext_id': 87932679100016,
#   'address': '33 RUE DE LA REPUBLIQUE, 30160 BESSEGES',
#   'lat': 44.29097299999999,
#   'lng': 4.098467},
#  {'ext_id': 92018319100013, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 79941877700014,
#   'address': '10 RUE AMBROISE THOMAS, 75009 PARIS',
#   'lat': 48.874711000000005,
#   'lng': 2.347471999999999},
#  {'ext_id': 39198886200010,
#   'address': '18 BOULEVARD DE BROU, 01000 BOURG-EN-BRESSE',
#   'lat': 46.204779,
#   'lng': 5.229393},
#  {'ext_id': 93096273300018,
#   'address': '21 RUE CHILDEBERT, 69002 LYON',
#   'lat': 45.76027295835639,
#   'lng': 4.8364870334098375},
#  {'ext_id': 84921059600011, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 90388875800013,
#   'address': "18 RUE DU SOLEIL D'OR, 31130 BALMA",
#   'lat': 43.607259999999975,
#   'lng': 1.5035600000000013},
#  {'ext_id': 82469203200017,
#   'address': '76 ROUTE DES COSTES, 06140 TOURRETTES-SUR-LOUP',
#   'lat': 43.719962999999986,
#   'lng': 7.067303999999999},
#  {'ext_id': 45090173100015,
#   'address': '5 RUE DE LA GRANGE BATELIERE, 75009 PARIS',
#   'lat': 48.87296999999998,
#   'lng': 2.3424470000000004},
#  {'ext_id': 34831176200010,
#   'address': None,
#   'lat': 43.389253,
#   'lng': 5.620702},
#  {'ext_id': 30618389800031,
#   'address': '12 PLACE AYMARD FAYARD, 87700 AIXE-SUR-VIENNE',
#   'lat': 45.79578199999999,
#   'lng': 1.1362570000000007},
#  {'ext_id': 91337253800011,
#   'address': '5 RUE DE SUISSE, 72100 LE MANS',
#   'lat': 47.99370999999998,
#   'lng': 0.22699800000000073},
#  {'ext_id': 89047262400018,
#   'address': None,
#   'lat': 43.450558999999984,
#   'lng': 3.4229280000000006},
#  {'ext_id': 91961467700012,
#   'address': '22 ALLEE HONORE BELLON, 06200 NICE',
#   'lat': 43.679626999999996,
#   'lng': 7.227712999999998},
#  {'ext_id': 42187020500034,
#   'address': '14 RUE DU COMMERCE, 91280 SAINT-PIERRE-DU-PERRAY',
#   'lat': 48.614553999999984,
#   'lng': 2.50661},
#  {'ext_id': 90207115800015,
#   'address': '12 RUE LOUIS BLANC, 76600 LE HAVRE',
#   'lat': 49.50723199999998,
#   'lng': 0.1254880000000007},
#  {'ext_id': 38946908100068,
#   'address': '37 AVENUE LEDRU-ROLLIN, 75012 PARIS',
#   'lat': 48.84768099999999,
#   'lng': 2.3705320000000003},
#  {'ext_id': 88760193800012,
#   'address': '16 AVENUE DE LA GARE, 15600 MAURS',
#   'lat': 44.70839899999998,
#   'lng': 2.1994259999999994},
#  {'ext_id': 49928453700010,
#   'address': '10 RUE FREDERIC BASTIAT, 40250 MUGRON',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 90994489400023,
#   'address': '47 BOULEVARD DES OCEANS, 13009 MARSEILLE',
#   'lat': 43.24184499999999,
#   'lng': 5.402847},
#  {'ext_id': 44502174400013,
#   'address': '3 RTE DE BABYLONE, 76430 LA REMUEE',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 94825492500019,
#   'address': '27 BOULEVARD DES ITALIENS, 75002 PARIS',
#   'lat': 48.87101499999998,
#   'lng': 2.3354389999999996},
#  {'ext_id': 40227142300046,
#   'address': '27 RUE MAURICE FLANDIN, 69003 LYON 3EME',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 53099553900042,
#   'address': '13 RUE DU FAUBOURG MONTMARTRE, 75009 PARIS',
#   'lat': 48.87238699999999,
#   'lng': 2.3430630000000003},
#  {'ext_id': 32829707200212,
#   'address': '23 RUE DE PARIS, 77340 PONTAULT-COMBAULT',
#   'lat': 48.777354999999986,
#   'lng': 2.5928489999999997},
#  {'ext_id': 43028807600028, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 80449721200048,
#   'address': '11 RUE DELPECH, 31000 TOULOUSE',
#   'lat': 43.601676,
#   'lng': 1.4511159999999994},
#  {'ext_id': 81115778300010,
#   'address': '1 IMPASSE DES CERISIERS, 69550 SAINT-JEAN-LA-BUSSIERE',
#   'lat': 46.003088999999996,
#   'lng': 4.327275},
#  {'ext_id': 53940560500012,
#   'address': '41 RUE TREVET, 93300 AUBERVILLIERS',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 90523874700018,
#   'address': '76 RUE NICOLAS APPERT, 44100 NANTES',
#   'lat': 47.214228,
#   'lng': -1.5825429999999991},
#  {'ext_id': 83454532900015,
#   'address': '65 RUE HONORE DAUMIER, 77000 LA ROCHETTE',
#   'lat': 48.52195199999997,
#   'lng': 2.660999},
#  {'ext_id': 83172937100037,
#   'address': '108 AVENUE GEORGES CLEMENCEAU, 69230 SAINT-GENIS-LAVAL',
#   'lat': 45.69816099350087,
#   'lng': 4.794560955593118},
#  {'ext_id': 48205832800055,
#   'address': '378 ROUTE DES ETANGS, 42320 CELLIEU',
#   'lat': 45.51852599999999,
#   'lng': 4.556588999999999},
#  {'ext_id': 45266370100061,
#   'address': '8 RUE POUVERIN, 83230 BORMES-LES-MIMOSAS',
#   'lat': 43.15081199999999,
#   'lng': 6.342551999999999},
#  {'ext_id': 37889784700018, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 45218166200027,
#   'address': '190 BOULEVARD DE CHARONNE, 75020 PARIS',
#   'lat': 48.85785999999998,
#   'lng': 2.392446},
#  {'ext_id': 89047328300012, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 89209922700019,
#   'address': '24 BOULEVARD BLANC, 13004 MARSEILLE',
#   'lat': 43.31162299999997,
#   'lng': 5.406632999999999},
#  {'ext_id': 90814764800012,
#   'address': '55 RUE CARTIER BRESSON, 93500 PANTIN',
#   'lat': 48.90217599999998,
#   'lng': 2.4006680000000014},
#  {'ext_id': 38478372600035,
#   'address': '48 AV DU GENERAL CHARLES DE GAULLE, 97300 CAYENNE',
#   'lat': -2.399366573922838,
#   'lng': 0.7342169484067204},
#  {'ext_id': 39969361300032,
#   'address': '2 RUE DES NEFLIERS, 30320 MARGUERITTES',
#   'lat': 43.86117899999999,
#   'lng': 4.443877},
#  {'ext_id': 32821693200017, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 38815605100020,
#   'address': '49 RUE JULES FERRY, 53000 LAVAL',
#   'lat': 48.07318599999999,
#   'lng': -0.7695909999999984},
#  {'ext_id': 34340353101785, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 51234975400014, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 44765375900012,
#   'address': '61 RUE DE TURENNE, 75003 PARIS 3',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 91206989500031, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 93061948100011,
#   'address': None,
#   'lat': 48.1189050147915,
#   'lng': -1.6781369634341},
#  {'ext_id': 94118035800017, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 80941231500016,
#   'address': '5 ALLEE DES VIGNES, 95550 BESSANCOURT',
#   'lat': 49.034629999999986,
#   'lng': 2.211761000000001},
#  {'ext_id': 48375896700028,
#   'address': None,
#   'lat': 43.66177400000001,
#   'lng': 0.6179280000000004},
#  {'ext_id': 94295105400017,
#   'address': '24 RUE ALBERT LECOCQ, 94170 LE PERREUX-SUR-MARNE',
#   'lat': 48.831780002780285,
#   'lng': 2.5035999395734625},
#  {'ext_id': 38348888900015, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 75362277800011,
#   'address': '170 ROUTE DE CANENX, 40090 SAINT-AVIT',
#   'lat': 43.93190899999999,
#   'lng': -0.4919359999999991},
#  {'ext_id': 50805037400018,
#   'address': '1 BD EOLE, 83400 HYERES',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 79205050200030,
#   'address': '1 RUE VICTOR HUGO, 57600 FORBACH',
#   'lat': 49.188131,
#   'lng': 6.912966999999997},
#  {'ext_id': 81248172900018,
#   'address': '57 RUE DE NEUILLY, 94120 FONTENAY-SOUS-BOIS',
#   'lat': 48.84752999999998,
#   'lng': 2.4776819999999997},
#  {'ext_id': 50486964500011, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 92926209500011, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 39876005800055, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 38007657000064, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 41371476700014, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 40989970500019, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 32954365600022, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 45279206200013, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 49824900200029,
#   'address': "5 RUE DE L'ANCIEN MOULIN, 23200 AUBUSSON",
#   'lat': 45.948016,
#   'lng': 2.1736980000000004},
#  {'ext_id': 49227908800016,
#   'address': '14 RTE DE LANGEAIS, 37130 COTEAUX-SUR-LOIRE',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 83185688500015,
#   'address': '2 RUE CHARLES BARBELET, 51360 PRUNAY',
#   'lat': 49.19655799999999,
#   'lng': 4.185960999999998},
#  {'ext_id': 98424899700012,
#   'address': '32 AVENUE PAUL DOUMER, 75016 PARIS',
#   'lat': 48.86065199999997,
#   'lng': 2.281981},
#  {'ext_id': 95135476000013,
#   'address': '7 RUE DU DOCTEUR LAFITTE, 51000 CHALONS-EN-CHAMPAGNE',
#   'lat': 48.968065999999986,
#   'lng': 4.355321000000001},
#  {'ext_id': 85388815400012, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 35011828700027,
#   'address': '2 RUE DES CLOS FOURS, 78930 GUERVILLE',
#   'lat': 48.968513,
#   'lng': 1.732285000000001},
#  {'ext_id': 82744166800056,
#   'address': '41 BOULEVARD VITAL BOUHOT, 92200 NEUILLY-SUR-SEINE',
#   'lat': 48.89722499999998,
#   'lng': 2.270600000000001},
#  {'ext_id': 40811370200018,
#   'address': None,
#   'lat': 44.773248999999986,
#   'lng': 1.8467850000000008},
#  {'ext_id': 45107039500038, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 39248681700019, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 90358247600011,
#   'address': '140 CHEMIN A DIARD, 74400 CHAMONIX-MONT-BLANC',
#   'lat': 45.914403999999976,
#   'lng': 6.858125999999999},
#  {'ext_id': 94125579600018, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 37845199100020,
#   'address': '26 ROUTE D’IRIGNY, 69530 BRIGNAIS',
#   'lat': 45.67315599999998,
#   'lng': 4.767311},
#  {'ext_id': 33425308500016,
#   'address': '129 ROUTE DE VERDUN, 57180 TERVILLE',
#   'lat': 49.34668999999999,
#   'lng': 6.135756999999999},
#  {'ext_id': 52428724000021,
#   'address': '33 RUE DE LA MAIRIE, 56120 LA GREE-SAINT-LAURENT',
#   'lat': 47.99572499999999,
#   'lng': -2.4983239999999993},
#  {'ext_id': 40422222600015,
#   'address': '18 AVENUE CARNOT, 54130 SAINT-MAX',
#   'lat': 48.69978799999998,
#   'lng': 6.205322999999998},
#  {'ext_id': 44342566500025,
#   'address': '19 RUE FRANCIS DE PRESSENSE, 69100 VILLEURBANNE',
#   'lat': 45.77252299999998,
#   'lng': 4.867890999999999},
#  {'ext_id': 94038525500010,
#   'address': "190 PLACE DE L'EGLISE, 88410 SAINT-JULIEN",
#   'lat': 48.019241979568235,
#   'lng': 5.895344990176113},
#  {'ext_id': 52150154400014,
#   'address': '827 RUE JEAN JAURES, 62700 BRUAY-LA-BUISSIERE',
#   'lat': 50.484949,
#   'lng': 2.5711910000000002},
#  {'ext_id': 95356520700016, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 94939607100019, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 52432804400010,
#   'address': '8 AV PAUL DOUMER, 92500 RUEIL-MALMAISON',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 48864594600028,
#   'address': '451 ROUTE DE CHABEUIL, 26000 VALENCE',
#   'lat': 44.923641999999994,
#   'lng': 4.931031999999999},
#  {'ext_id': 81477838700021,
#   'address': '36 RUE SCHEFFER, 75016 PARIS',
#   'lat': 48.86203699999999,
#   'lng': 2.2821870000000013},
#  {'ext_id': 40960909600055,
#   'address': '16 RUE LAMORICIERE, 44100 NANTES',
#   'lat': 47.21306099999998,
#   'lng': -1.571604999999998},
#  {'ext_id': 88904525800015, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 42143860700010, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 83907339200012, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 79466294000020,
#   'address': "1 AVENUE DE CHAMPFLEURY, 69410 CHAMPAGNE-AU-MONT-D'OR",
#   'lat': 45.798754999999986,
#   'lng': 4.789789999999999},
#  {'ext_id': 30342971600028,
#   'address': '34 RTE DE DOUAI, 62450 BAPAUME',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 48384510300033,
#   'address': "8 QUAI DE LA GARE D'EAU, 69700 GIVORS",
#   'lat': 45.586158999999995,
#   'lng': 4.771837999999999},
#  {'ext_id': 79971944800018,
#   'address': '485 ALLEE DES CIGALES, 47700 CASTELJALOUX',
#   'lat': 44.29411297149855,
#   'lng': 0.07446704492675274},
#  {'ext_id': 87952398300010,
#   'address': '19 RUE DU MARECHAL JOFFRE, 78000 VERSAILLES',
#   'lat': 48.795892999999985,
#   'lng': 2.122061},
#  {'ext_id': 79607729500015, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 50394195700014,
#   'address': '12 BOULEVARD VICTOR ETIENNE, 22600 LOUDEAC',
#   'lat': 48.17263399999999,
#   'lng': -2.7522209999999987},
#  {'ext_id': 42983281900016,
#   'address': '47 RUE SAINT-JULIEN, 49100 ANGERS',
#   'lat': 47.46928499999998,
#   'lng': -0.5500879999999992},
#  {'ext_id': 50414170600052,
#   'address': '149 RUE SAINT DENIS, 75002 PARIS 2',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 50921831900010,
#   'address': '7 RUE MAZAGRAN, 97400 SAINT-DENIS',
#   'lat': 56.13765002099487,
#   'lng': -2.724737934958296},
#  {'ext_id': 32519727500036,
#   'address': '21 RUE DE DINAN, 35730 PLEURTUIT',
#   'lat': 48.57865599999998,
#   'lng': -2.0585919999999978},
#  {'ext_id': 79403372000036,
#   'address': '69 AV FRANKLIN D ROOSEVELT, 75008 PARIS 8',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 50953818700022, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 93772492000015,
#   'address': '28 RUE LOUIS MALLE, 29200 BREST',
#   'lat': 48.36965701415639,
#   'lng': -4.536530061168367},
#  {'ext_id': 1956818700017,
#   'address': '24 RUE CARNOT, 05000 GAP',
#   'lat': 44.55809499999998,
#   'lng': 6.079963999999998},
#  {'ext_id': 91739732500015,
#   'address': '33 CHEMIN DU PETIT PESSICART, 06100 NICE',
#   'lat': 43.71636099999999,
#   'lng': 7.243820999999999},
#  {'ext_id': 88881145200042,
#   'address': '4 RUE DU VIEUX COLLEGE, 71400 AUTUN',
#   'lat': 46.95023803880216,
#   'lng': 4.2965899496374975},
#  {'ext_id': 30976131000064,
#   'address': None,
#   'lat': 45.35349599999999,
#   'lng': 1.6896240000000011},
#  {'ext_id': 34047463400011, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 39430919900013,
#   'address': '5 RUE DES DEPORTES, 88700 RAMBERVILLERS',
#   'lat': 48.34428799999998,
#   'lng': 6.628003999999997},
#  {'ext_id': 88164352200017,
#   'address': None,
#   'lat': 47.356201999999996,
#   'lng': -1.5910019999999987},
#  {'ext_id': 83996112500011,
#   'address': '103 RUE EDOUARD VAILLANT, 95870 BEZONS',
#   'lat': 48.925627999999996,
#   'lng': 2.2115630000000004},
#  {'ext_id': 84063890200014,
#   'address': '4 RUE DES LYANES, 75020 PARIS',
#   'lat': 48.862939999999995,
#   'lng': 2.4062469999999996},
#  {'ext_id': 44103581300043,
#   'address': '30 ALLEE DES GRAVELLES, 87280 LIMOGES',
#   'lat': 45.88725399999999,
#   'lng': 1.2754760000000005},
#  {'ext_id': 92174046000016, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 49284827000012,
#   'address': '35 RUE SAINT-ANDRE DES ARTS, 75006 PARIS',
#   'lat': 48.85330899999998,
#   'lng': 2.341669000000001},
#  {'ext_id': 88821983900014,
#   'address': '7 LOTISSEMENT D’ORLEANS, 97129 LAMENTIN',
#   'lat': 6.3036963893957765,
#   'lng': 2.6021614065652323},
#  {'ext_id': 50486900900010,
#   'address': '16 RUE BARNAVE, 38000 GRENOBLE',
#   'lat': 45.19252999999998,
#   'lng': 5.730192999999998},
#  {'ext_id': 84225922800018, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 84872977800011,
#   'address': '1 ALLEE AUGUSTE-LOUIS JOBBE DUVAL, 35000 RENNES',
#   'lat': 48.10632599999997,
#   'lng': -1.6888379999999972},
#  {'ext_id': 84969339500014,
#   'address': '1 RUE DE LA TOUCHE, 41120 CHITENAY',
#   'lat': 47.49836199999999,
#   'lng': 1.3727280000000004},
#  {'ext_id': 51907994100018,
#   'address': None,
#   'lat': 42.74217300000001,
#   'lng': 2.886491},
#  {'ext_id': 80833761200028,
#   'address': '38 RUE LOUIS ETERLET, 77500 CHELLES',
#   'lat': 48.87894999999999,
#   'lng': 2.5885310000000006},
#  {'ext_id': 84427893700033,
#   'address': '33 RUE MONTMARTRE, 75002 PARIS',
#   'lat': 48.865059999999986,
#   'lng': 2.3448660000000014},
#  {'ext_id': 38090820200027,
#   'address': None,
#   'lat': 46.36937799999998,
#   'lng': 2.378356},
#  {'ext_id': 84967377700017, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 51249656300044,
#   'address': '5 PLACE DU SANITAT, 44100 NANTES',
#   'lat': 47.209958999999984,
#   'lng': -1.569077999999998},
#  {'ext_id': 44856259500018,
#   'address': None,
#   'lat': 46.02533099999999,
#   'lng': 1.516847000000001},
#  {'ext_id': 32905351600012,
#   'address': '29 RUE JEAN JAURES, 66170 MILLAS',
#   'lat': 42.691505999999976,
#   'lng': 2.6963000000000004},
#  {'ext_id': 98824740900010, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 52335069200019,
#   'address': '7 RUE DU PRESBYTERE, 69530 BRIGNAIS',
#   'lat': 45.673889999999986,
#   'lng': 4.758506},
#  {'ext_id': 83881690800027,
#   'address': '9004 RUE DE MONTMARTRE, 50100 CHERBOURG-EN-COTENTIN',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 78805803006708,
#   'address': "72 RUE DE L'HOTEL DE VILLE, 59240 DUNKERQUE",
#   'lat': 51.045867999999984,
#   'lng': 2.3961200000000002},
#  {'ext_id': 44120890700010, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 45225142400027,
#   'address': '5 RUE VERCINGETORIX, 75014 PARIS',
#   'lat': 48.837997999999985,
#   'lng': 2.3214650000000003},
#  {'ext_id': 40971992900013,
#   'address': '16 RUE DES YVELINES, 28320 ECROSNES',
#   'lat': 48.547683999999975,
#   'lng': 1.7288390000000005},
#  {'ext_id': 17340211600185, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 80984276800016,
#   'address': None,
#   'lat': 46.74413099999999,
#   'lng': -1.1775389999999974},
#  {'ext_id': 98213200300012,
#   'address': '6 ALLEE JACQUARD, 86580 VOUNEUIL-SOUS-BIARD',
#   'lat': 46.603119999999976,
#   'lng': 0.3041920000000005},
#  {'ext_id': 32568498300050, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 89915543600012,
#   'address': '10 RUE DE PENTHIEVRE, 75008 PARIS',
#   'lat': 48.87305699999998,
#   'lng': 2.3166050000000005},
#  {'ext_id': 83005021700033, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 34033839100113,
#   'address': '5 RUE D AMIENS, 60200 COMPIEGNE',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 50898120600016, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 92540495600011,
#   'address': '650 CHEMIN LARRE - LUZEA, 64210 AHETZE',
# ...
#  {'ext_id': 41277166900014,
#   'address': None,
#   'lat': 50.240346999999986,
#   'lng': 3.711169999999999},
#  {'ext_id': 77558923700251,
#   'address': '450 AVENUE DU MARECHAL JUIN, 34200 SETE',
#   'lat': 43.408721999999976,
#   'lng': 3.7049859999999994},
#  {'ext_id': 34244019500051, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 53994761400019,
#   'address': None,
#   'lat': 44.14753599999998,
#   'lng': 0.7486160000000013},
#  {'ext_id': 39961176300125,
#   'address': '1 RUE DE LA MARE A LA BESSE, 17000 LA ROCHELLE',
#   'lat': 46.16087899999998,
#   'lng': -1.2172649999999994},
#  {'ext_id': 31238137900014,
#   'address': '15 RUE LA CONDAMINE, 75017 PARIS',
#   'lat': 48.88740699999999,
#   'lng': 2.3237669999999997},
#  {'ext_id': 5780232400012,
#   'address': '8 RUE ROUVIERE, 13001 MARSEILLE',
#   'lat': 43.29473399999999,
#   'lng': 5.37975},
#  {'ext_id': 42972338000037,
#   'address': None,
#   'lat': 45.37492499999999,
#   'lng': 4.276414999999999},
#  {'ext_id': 40148486000028,
#   'address': '83 CHAUSSEE JULES CESAR, 95130 FRANCONVILLE',
#   'lat': 48.99671099999998,
#   'lng': 2.235914},
#  {'ext_id': 82130748500028,
#   'address': '9 RUE DU PUITS, 17250 PLASSAY',
#   'lat': 45.8315990415174,
#   'lng': -0.7197640010535556},
#  {'ext_id': 41152179200019, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 51464947400012, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 94338140000010, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 33508547800014,
#   'address': '12 PARC DE LA BERENGERE, 92210 SAINT-CLOUD',
#   'lat': 48.85834099999999,
#   'lng': 2.2121470000000003},
#  {'ext_id': 89753045700026,
#   'address': '10 RUE DU PRIEURE, 44520 LA MEILLERAYE-DE-BRETAGNE',
#   'lat': 47.55786697207992,
#   'lng': -1.402223932090975},
#  {'ext_id': 48529127200014,
#   'address': "222 AV FRANCOIS MITTERRAND, 85100 LES SABLES D'OLONNE",
#   'lat': None,
#   'lng': None},
#  {'ext_id': 89824275500012, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 39070389002468,
#   'address': '7 RTE DES ORCHIDEES, 01250 NIVIGNE ET SURAN',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 92287493800017,
#   'address': '9 PLACE LOUISE DE VILMORIN, 94450 LIMEIL-BREVANNES',
#   'lat': 48.752369,
#   'lng': 2.475604000000001},
#  {'ext_id': 79437527900021, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 94418980200019,
#   'address': '178 RUE DU JEU DE BALLE, 62110 HENIN-BEAUMONT',
#   'lat': 50.41870702482416,
#   'lng': 2.9599010254697284},
#  {'ext_id': 53010141900014, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 88936630800019,
#   'address': '7 RUE DE SONTAY, 75016 PARIS',
#   'lat': 48.87039799999997,
#   'lng': 2.2842410000000015},
#  {'ext_id': 79980527000029,
#   'address': '5 RUE DE LA TUILERIE, 16510 VERTEUIL-SUR-CHARENTE',
#   'lat': 45.98201099999999,
#   'lng': 0.23927600000000118},
#  {'ext_id': 33310292900010,
#   'address': '19 AVENUE DE LA LIBERATION, 27110 LE NEUBOURG',
#   'lat': 49.14578699999999,
#   'lng': 0.9020210000000007},
#  {'ext_id': 33825323013236,
#   'address': '9 QUAI JULES GUESDE, 94400 VITRY-SUR-SEINE',
#   'lat': 48.77822099999999,
#   'lng': 2.4141130000000004},
#  {'ext_id': 81748999000017,
#   'address': '11 AVENUE DES CITEAUX, 45190 TAVERS',
#   'lat': 47.768019999999986,
#   'lng': 1.6174870000000015},
#  {'ext_id': 85175484600018,
#   'address': '30 RUE DU PRE SAINT GERVAIS, 93500 PANTIN',
#   'lat': 48.88964299999998,
#   'lng': 2.4032690000000008},
#  {'ext_id': 94785149900014,
#   'address': '1 RUE PAUL BAUDRY, 75008 PARIS',
#   'lat': 48.871951999999986,
#   'lng': 2.3062550000000006},
#  {'ext_id': 38523239200014,
#   'address': '27 PLACE BELLECOUR, 69002 LYON',
#   'lat': 45.75691799999999,
#   'lng': 4.8304399999999985},
#  {'ext_id': '38317521300024',
#   'address': '24 RUE DE LA FAIENCERIE, 54400 LONGWY',
#   'lat': 49.510631999999994,
#   'lng': 5.770509999999998},
#  {'ext_id': 53151189700070, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 40751213600042,
#   'address': '13 RUE DE VANVES, 92100 BOULOGNE-BILLANCOURT',
#   'lat': 48.83418499999998,
#   'lng': 2.25247},
#  {'ext_id': 35230022200010,
#   'address': "19 RUE D'ITALIE, 13006 MARSEILLE",
#   'lat': 43.29021199999996,
#   'lng': 5.381992999999998},
#  {'ext_id': 92857468000015,
#   'address': None,
#   'lat': 45.447922009842,
#   'lng': 6.979801020277292},
#  {'ext_id': 84287547800013,
#   'address': "12 RUE DES CARRIERES D'AMERIQUE, 75019 PARIS",
#   'lat': 48.88471899999999,
#   'lng': 2.3932580000000003},
#  {'ext_id': 33923795000037,
#   'address': '12 RES KERCADO ARMORIQUE, 56000 VANNES',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 51129776400025,
#   'address': '1 RUE PAUL CEZANNE, 34500 BEZIERS',
#   'lat': 43.357272999999985,
#   'lng': 3.2342080000000006},
#  {'ext_id': 91981869000019,
#   'address': "20 CHEMIN DE L'AUNAY, 72290 SOULIGNE-SOUS-BALLON",
#   'lat': 48.13463299999999,
#   'lng': 0.23468800000000128},
#  {'ext_id': 32802212400023, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 79230222600024,
#   'address': '1 IMPASSE DE CAPAYAN, 33470 GUJAN-MESTRAS',
#   'lat': 44.62563899999998,
#   'lng': -1.0566009999999983},
#  {'ext_id': 44801500800015,
#   'address': '47 RUE EDGAR AVRIL, 97430 LE TAMPON',
#   'lat': 55.75267050881556,
#   'lng': -2.5531414749559964},
#  {'ext_id': 51233374100027, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 82142483500022, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 81432302800013,
#   'address': '2 RUE DES MARAIS, 78100 SAINT-GERMAIN-EN-LAYE',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 98923791200013, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 45040756400019,
#   'address': '3371 CORNICHE MARIUS ESCARTEFIGUE, 83200 TOULON',
#   'lat': 43.137048999999976,
#   'lng': 5.9668849999999996},
#  {'ext_id': 80802364200016,
#   'address': '22 RUE BARBERIS, 06300 NICE',
#   'lat': 43.70463299999998,
#   'lng': 7.284789000000001},
#  {'ext_id': 48211504500023,
#   'address': '203 RUE DU MARECHAL JUIN, 30130 PONT-SAINT-ESPRIT',
#   'lat': 44.251703999999975,
#   'lng': 4.645239999999999},
#  {'ext_id': 37903034900011,
#   'address': '9 RUE DE LA TOUR D’AUVERGNE, 29400 LANDIVISIAU',
#   'lat': 48.50847299999998,
#   'lng': -4.072452999999996},
#  {'ext_id': 38192283000017,
#   'address': '13 RUE JEANNE D ARC, 54350 MONT-SAINT-MARTIN',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 90043043000018,
#   'address': '37 RUE DES MANISES, 08440 VIVIER-AU-COURT',
#   'lat': 49.736704,
#   'lng': 4.821985999999999},
#  {'ext_id': 47911800200092,
#   'address': '1 IMP DU COUVENT, 56590 GROIX',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 78078702400014, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 88522066500016,
#   'address': '55 ROUTE DE LA COURNEUVE, 93200 SAINT-DENIS',
#   'lat': 48.93178399999999,
#   'lng': 2.379122},
#  {'ext_id': 42321312300015,
#   'address': '2 RUE CHARLES LEMAUX, 71530 CHAMPFORGEUIL',
#   'lat': 46.82004999999999,
#   'lng': 4.836512999999999},
#  {'ext_id': 40821597800011,
#   'address': '1672 AVENUE DE MAURIN, 34000 MONTPELLIER',
#   'lat': 43.59039399999998,
#   'lng': 3.8731479999999996},
#  {'ext_id': 34074880500017, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 39953497300017, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 83244143000010,
#   'address': '7 ROUTE DE TRENIDO, 56220 SAINT-GRAVE',
#   'lat': 47.722038999999995,
#   'lng': -2.280975999999997},
#  {'ext_id': 79279874600022,
#   'address': '15 RUE PIERRE BROSSOLETTE, 31140 MONTBERON',
#   'lat': 43.720906,
#   'lng': 1.480301000000001},
#  {'ext_id': 79029286600015,
#   'address': '26 RUE PLANCHAT, 75020 PARIS 20',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 90911050400026,
#   'address': '4 RUE PORTE JAUNE, 18000 BOURGES',
#   'lat': 47.08444797858364,
#   'lng': 2.3968500472524714},
#  {'ext_id': 80133890600010,
#   'address': '22 RUE DU MARECHAL JOFFRE, 37550 SAINT-AVERTIN',
#   'lat': 47.363233999999984,
#   'lng': 0.722776000000002},
#  {'ext_id': 43387205800014,
#   'address': '10 RUE DES SAULES, 59840 PERENCHIES',
#   'lat': 50.665178,
#   'lng': 2.979833},
#  {'ext_id': 88522076400017, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 51045766600046,
#   'address': None,
#   'lat': 49.43498799999999,
#   'lng': 1.1034450000000011},
#  {'ext_id': 57210217620779,
#   'address': '209 RUE DU ROC, 81000 ALBI',
#   'lat': 43.92037699999999,
#   'lng': 2.161771},
#  {'ext_id': 35407218300016, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 34480522100027, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 41439334800019, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 33245483400034,
#   'address': '8 ROUTE DE FORFRY, 77165 SAINT-SOUPPLETS',
#   'lat': 49.04324199999997,
#   'lng': 2.813482},
#  {'ext_id': '41882841400015', 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 40224162400012, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 32097449600053,
#   'address': '26 RUE FEUTRIER, 75018 PARIS',
#   'lat': 48.88702899999998,
#   'lng': 2.3460380000000005},
#  {'ext_id': 90799640900013, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 83334590300011,
#   'address': '5 RUE DES ROMAINS, 57570 BREISTROFF-LA-GRANDE',
#   'lat': 49.46040299999998,
#   'lng': 6.220692999999998},
#  {'ext_id': 84021108000014,
#   'address': '12 AVENUE ALBERT PLEUVRY, 94370 SUCY-EN-BRIE',
#   'lat': 48.76884899999998,
#   'lng': 2.514664000000001},
#  {'ext_id': 35010915300022,
#   'address': '3 RUE DES CHAMPIGNONS, 67800 HŒNHEIM',
#   'lat': 48.619590999999986,
#   'lng': 7.754265999999999},
#  {'ext_id': 50759094100021,
#   'address': '23 RUE DE LA PEGOU, 31620 BOULOC',
#   'lat': 43.77656699999999,
#   'lng': 1.410558},
#  {'ext_id': 84492864800055,
#   'address': '23 AV LONGUEIL, 78600 MAISONS-LAFFITTE',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 48808638000018,
#   'address': '23 RUE DES ECOUFFES, 75004 PARIS',
#   'lat': 48.85709599999998,
#   'lng': 2.358771000000001},
#  {'ext_id': 82286931900019,
#   'address': '221 RUE LA FAYETTE, 75010 PARIS',
#   'lat': 48.881586999999996,
#   'lng': 2.3653189999999995},
#  {'ext_id': 84843243100015,
#   'address': None,
#   'lat': 49.16751299999999,
#   'lng': 2.3578279999999996},
#  {'ext_id': 39829297900018,
#   'address': '26 AVENUE DU STADE, 35650 LE RHEU',
#   'lat': 48.10065599999999,
#   'lng': -1.8022039999999977},
#  {'ext_id': 48438218900013, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 40440872600010,
#   'address': '7 PLACE DU 11 NOVEMBRE 1918, 93000 BOBIGNY',
#   'lat': 48.909025,
#   'lng': 2.4422360000000003},
#  {'ext_id': 51779702300036, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 52029938900012,
#   'address': '55 RUE SADI CARNOT, 59211 SANTES',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 44229221500013,
#   'address': '16 RUE DU CHATEAU, 59140 DUNKERQUE',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 75079545200028,
#   'address': '1 RUE HENRI CLAUSSE, 93000 BOBIGNY',
#   'lat': 48.91290799232781,
#   'lng': 2.4660999648404993},
#  {'ext_id': 79893070700012,
#   'address': '68 RUE RACHAIS, 69007 LYON',
#   'lat': 45.74948599999999,
#   'lng': 4.8494779999999995},
#  {'ext_id': 77630241600024,
#   'address': '12 RUE SAINTE CATHERINE, 42000 SAINT-ETIENNE',
#   'lat': 45.43680899999998,
#   'lng': 4.386081999999999},
#  {'ext_id': 81795036300025, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 52997315800015,
#   'address': None,
#   'lat': 45.04365699999999,
#   'lng': 5.034939999999998},
#  {'ext_id': 42888830900013,
#   'address': '1 RUE DE DREUX, 27810 MARCILLY-SUR-EURE',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 92477627100018,
#   'address': '5 AVENUE PAVLOV, 78190 TRAPPES',
#   'lat': 48.78579601520444,
#   'lng': 1.9752479588736482},
#  {'ext_id': 50209589600010,
#   'address': "17 RUE DE L'EGLISE, 23380 AJAIN",
#   'lat': 46.20810299999998,
#   'lng': 1.9983810000000009},
#  {'ext_id': 43837554500029,
#   'address': '26 AVENUE JEAN JAURES, 69007 LYON',
#   'lat': 45.751939,
#   'lng': 4.845622},
#  {'ext_id': 50187975300017, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 77505973600063,
#   'address': None,
#   'lat': 46.99317099999998,
#   'lng': 2.245428000000001},
#  {'ext_id': 98145025700010,
#   'address': '512 BOULEVARD DE LA REPUBLIQUE, 13300 SALON-DE-PROVENCE',
#   'lat': 43.640177999999985,
#   'lng': 5.089097},
#  {'ext_id': 21380563300202,
#   'address': '32 AVENUE JULES RAVAT, 38500 VOIRON',
#   'lat': 45.369188999999984,
#   'lng': 5.585227999999998},
#  {'ext_id': 80082972300025,
#   'address': '12 RUE ARISTIDE OLLIVIER, 34000 MONTPELLIER',
#   'lat': 43.60674799999998,
#   'lng': 3.8816990000000002},
#  {'ext_id': 88373428700013, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 38892146200023,
#   'address': '6 AVENUE ISABELLE, 44500 LA BAULE-ESCOUBLAC',
#   'lat': 47.28569699999998,
#   'lng': -2.406470999999996},
#  {'ext_id': 54002197900013,
#   'address': '12 RUE JACQUES BIZET, 85200 FONTENAY-LE-COMTE',
#   'lat': 46.454835999999986,
#   'lng': -0.8015619999999982},
#  {'ext_id': 88822977000019,
#   'address': '42 ROUTE DE BORDEAUX, 33360 LATRESNE',
#   'lat': 44.79105499999998,
#   'lng': -0.5005449999999988},
#  {'ext_id': 52760344300021, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 53199933200020, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 49792993500011, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 31926218400041,
#   'address': '5 BOULEVARD AUGUSTE GAUDIN, 20200 BASTIA',
#   'lat': 42.694552,
#   'lng': 9.448898},
#  {'ext_id': 92514241600013,
#   'address': '8 RUE DES ASPRES, 66550 CORNEILLA-LA-RIVIERE',
#   'lat': 42.69788904204164,
#   'lng': 2.735148008370549},
#  {'ext_id': 34147224900018,
#   'address': '31 RUE PAUL YVAN LAGARDE, 73200 ALBERTVILLE',
#   'lat': 45.67153999999996,
#   'lng': 6.383222999999998},
#  {'ext_id': 82882931700027,
#   'address': '357 CHEMIN DU GAS GARDONNET, 30100 ALES',
#   'lat': 44.10769199999998,
#   'lng': 4.106403},
#  {'ext_id': 83352834200029,
#   'address': "86 RUE JOUFFROY D'ABBANS, 75017 PARIS",
#   'lat': 48.883411999999986,
#   'lng': 2.3037960000000006},
#  {'ext_id': 52352016100044,
#   'address': '194 AVENUE DES ROMARINS, 34130 SAINT-AUNES',
#   'lat': 43.650812,
#   'lng': 3.975661},
#  {'ext_id': 68181136000012,
#   'address': '87 RUE DE SAINTES, 16000 ANGOULEME',
#   'lat': 45.657780999999986,
#   'lng': 0.1459210000000004},
#  {'ext_id': 37894428400058,
#   'address': '110 AVENUE DU GENERAL LECLERC, 93500 PANTIN',
#   'lat': 48.89923599999999,
#   'lng': 2.409169},
#  {'ext_id': 81761721000015, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 84057131900010,
#   'address': '7 ALLEE DES 2 CHATEAUX, 77600 BUSSY-SAINT-GEORGES',
#   'lat': 48.84099999999998,
#   'lng': 2.7011369999999997},
#  {'ext_id': 84451431500010,
#   'address': '6 ROUTE DU PUITS DES BROUSSES, 17610 CHERAC',
#   'lat': 45.705577999999974,
#   'lng': -0.4526859999999988},
#  {'ext_id': 45317037500027,
#   'address': None,
#   'lat': 43.38962499999998,
#   'lng': 5.146913999999999},
#  {'ext_id': 52201586600018, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 84050904600016, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 39048647000011,
#   'address': '47 CRS MARECHAL GALLIENI, 33000 BORDEAUX',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 42812130500026,
#   'address': '314 RTE DE BETHUNE, 62300 LENS',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 79303906600014,
#   'address': '4 CHEMIN ERA POUTJA, 65200 CIEUTAT',
#   'lat': 43.12575699999999,
#   'lng': 0.20465300000000153},
#  {'ext_id': 30692871400022,
#   'address': '76 BD D ARMENTIERES, 59100 ROUBAIX',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 82982024000028,
#   'address': '14 RUE DU DOUET FOURCHE, 35800 DINARD',
#   'lat': 48.62168899999998,
#   'lng': -2.0587809999999984},
#  {'ext_id': 84224252100016,
#   'address': '120 ROUTE D’ARBIGNIEU, 01300 BELLEY',
#   'lat': 45.754410999999976,
#   'lng': 5.678854},
#  {'ext_id': 41389302500010,
#   'address': "5 BOULEVARD GABRIEL GUIST'HAU, 44000 NANTES",
#   'lat': 47.215493999999964,
#   'lng': -1.5647819999999972},
#  {'ext_id': 44500680200042,
#   'address': '6 RTE DE CREIL, 60300 SENLIS',
#   'lat': None,
#   'lng': None},
#  {'ext_id': 33011083400018,
#   'address': '13 RUE DU JURA, 75013 PARIS',
#   'lat': 48.837228,
#   'lng': 2.3561609999999997},
#  {'ext_id': 45362689700012, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 40973402700025, 'address': None, 'lat': None, 'lng': None},
#  {'ext_id': 79320685500033,
#   'address': "62 RUE JOUFFROY D'ABBANS, 75017 PARIS",
#   'lat': 48.88469499999999,
#   'lng': 2.306108}]

# %%
from batid.services.guess_bdg_new import Guesser, GeocodeNameHandler, GeocodeAddressHandler, ClosestFromPointHandler
guesses_path = "./guesses.json"
guesser = Guesser(batch_size=90)
guesser.handlers = [
    GeocodeAddressHandler(),
    ClosestFromPointHandler()
]
guesser.create_work_file(list(sample_inputs), guesses_path)
guesser.guess_work_file(guesses_path)
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]

# %%
guesser = Guesser()
guesser.load_work_file(guesses_path)
guesser.report()
# Out:
# -- Report --
# Number of rows: 1000
# Number of match: 571 (57.10%)
#
# -- finished_steps --
# Rows with finished_steps closest_from_point: 1000 (100.00%)
# Rows with finished_steps geocode_address: 1000 (100.00%)
# Rows with finished_steps geocode_name: 0 (0.00%)
# Rows with empty finished_steps: 0 (0.00%)
#
# -- match_reasons : absolute --
# match_reason
# precise_address_match    535
# point_on_bdg              18
# isolated_closest_bdg      18
# Name: count, dtype: int64
#
# -- match_reasons : % --
# match_reason
# precise_address_match    53.5
# point_on_bdg              1.8
# isolated_closest_bdg      1.8
# Name: count, dtype: float64
#
# -- Inputs --
# rows with ban_id: 584 (58.40%)

# %%
guesser.to_csv(os.path.join(data_path, 'results.csv'), ext_id_col_name="ext_id")
