# %% [markdown]
# ## Faire tourner des tests dans un Notebook
#
# Je ne sais pas encore si ça va nous être utile ou pas, j'ai fait ça pour voir comment les tests permettent de travailler dans une base de donnée sandboxée

# %%
import os
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
from django.test import TestCase
from batid.models import Building

# %%
class MyTests(TestCase):
    @classmethod
    def setUpTestData(cls):
        # Set up data for the whole TestCase
        
        # very fast way to empty the building table!
        from django.db import connection
        cursor = connection.cursor()
        cursor.execute('TRUNCATE TABLE batid_building CASCADE' )
        # Building.objects.all().delete()
        # création du village
        cursor.execute('''
        
        INSERT INTO batid_building (rnb_id,"source",point,ext_bdnb_id,ext_bdtopo_id,shape,created_at,updated_at) VALUES
	 ('6F7HRXDNWRUF','bdtopo','SRID=2154;POINT (898517.9248015874 6450632.55)','','BATIMENT0000000302585971','SRID=2154;MULTIPOLYGON (((898516.8 6450631.3, 898517.1 6450634, 898519 6450633.8, 898518.8 6450631, 898516.8 6450631.3)))','2023-09-20 11:37:40.228','2023-09-20 11:37:40.228'),
	 ('2MG793YGTMHG','bdtopo','SRID=2154;POINT (898502.7366666667 6450731)','','BATIMENT0000000302585861','SRID=2154;MULTIPOLYGON (((898508.4 6450725.8, 898496.1 6450727.2, 898496.9 6450736.2, 898509.5 6450734.8, 898508.4 6450725.8)))','2023-09-20 11:37:41.641','2023-09-20 11:37:41.641'),
	 ('C9MV8XZJYH4E','bdtopo','SRID=2154;POINT (898460.6831896552 6450790.55)','','BATIMENT0000000302585767','SRID=2154;MULTIPOLYGON (((898459.2 6450788.4, 898459.2 6450789, 898459.3 6450792.1, 898457.6 6450792.2, 898457.7 6450793.9, 898462.3 6450794.1, 898462 6450788.3, 898459.2 6450788.4)))','2023-09-20 11:39:39.329','2023-09-20 11:39:39.329'),
	 ('TRX6GZL9F7Z2','bdtopo','SRID=2154;POINT (898455.3165711008 6450784.550000001)','','BATIMENT0000000302585768','SRID=2154;MULTIPOLYGON (((898459.2 6450788.4, 898458.9 6450780, 898451.5 6450780.4, 898451.5 6450780.7, 898451.7 6450791.6, 898457.5 6450791.5, 898457.5 6450789.1, 898459.2 6450789, 898459.2 6450788.4)))','2023-09-20 11:39:39.329','2023-09-20 11:39:39.329'),
	 ('EDZ8DNT2WYRF','bdtopo','SRID=2154;POINT (898478.7114086049 6450787.65)','','BATIMENT0000000302585850','SRID=2154;MULTIPOLYGON (((898475.1 6450793.2, 898483.3 6450792.8, 898482.2 6450781.7, 898474.2 6450782.5, 898475.1 6450793.2)))','2023-09-20 11:39:39.330','2023-09-20 11:39:39.330'),
	 ('VXYBECAF9LRN','bdtopo','SRID=2154;POINT (898505.8701257862 6450688.2)','','BATIMENT0000000302585810','SRID=2154;MULTIPOLYGON (((898499.4 6450694.1, 898500.3 6450700.8, 898504.7 6450700.1, 898504.4 6450698.7, 898510.9 6450697.6, 898508.6 6450681.7, 898501.5 6450682.9, 898502.9 6450693.5, 898499.4 6450694.1)))','2023-09-20 11:39:39.331','2023-09-20 11:39:39.331'),
	 ('7EA5YU9DRWAA','bdtopo','SRID=2154;POINT (898515.7827493688 6450657.15)','','BATIMENT0000000302585819','SRID=2154;MULTIPOLYGON (((898509.7 6450653, 898511.5 6450662.6, 898521.8 6450661.3, 898520.1 6450651.4, 898509.7 6450653)))','2023-09-20 11:39:39.331','2023-09-20 11:39:39.331'),
	 ('FMAMJ9RDANXZ','bdtopo','SRID=2154;POINT (898543.6520753219 6450659.949999999)','','BATIMENT0000000302585759','SRID=2154;MULTIPOLYGON (((898538.4 6450654.3, 898540.8 6450667, 898548.8 6450665.6, 898546.6 6450652.7, 898538.4 6450654.3)))','2023-09-20 11:39:39.317','2023-09-20 11:39:39.317'),
	 ('JHZA55AKJWEM','bdtopo','SRID=2154;POINT (898576.1475967986 6450764.9)','','BATIMENT0000000302585757','SRID=2154;MULTIPOLYGON (((898572.3 6450758.1, 898574.9 6450773.8, 898579.8 6450773, 898581.3 6450781.7, 898586.4 6450780.9, 898585.4 6450774.4, 898585 6450771.7, 898580.3 6450772.4, 898577.4 6450757.2, 898572.3 6450758.1)))','2023-09-20 11:39:39.329','2023-09-20 11:39:39.329'),
	 ('Z39URVDZ9A39','bdtopo','SRID=2154;POINT (898557.9864999994 6450703.550000001)','','BATIMENT0000000302585887','SRID=2154;MULTIPOLYGON (((898563.7 6450699, 898562.8 6450699.3, 898554.1 6450702.5, 898553.8 6450701.8, 898551.4 6450702.7, 898553.3 6450707.7, 898563.2 6450703.9, 898565.3 6450703.2, 898563.7 6450699)))','2023-09-20 11:39:39.333','2023-09-20 11:39:39.333'),
	 ('LB6F9RW9LZY8','bdtopo','SRID=2154;POINT (898559.05 6450820.65)','','BATIMENT0000000302585945','SRID=2154;MULTIPOLYGON (((898554.3 6450827.2, 898562.3 6450828, 898563.8 6450814.1, 898555.8 6450813.3, 898554.3 6450827.2)))','2023-09-20 11:39:39.334','2023-09-20 11:39:39.334'),
	 ('PGHQKLUGLSMA','bdtopo','SRID=2154;POINT (898576.144736842 6450796.05)','','BATIMENT0000000302585963','SRID=2154;MULTIPOLYGON (((898580.4 6450789.4, 898573.4 6450789.5, 898573.4 6450788, 898568.9 6450788.1, 898569.1 6450799.5, 898583.3 6450799.1, 898583.2 6450793, 898583.2 6450792.6, 898580.5 6450792.6, 898580.4 6450789.4)))','2023-09-20 11:39:39.335','2023-09-20 11:39:39.335'),
	 ('65KK7PGJQB9W','bdtopo','SRID=2154;POINT (898574.3171006108 6450677.1)','','BATIMENT0000000302585969','SRID=2154;MULTIPOLYGON (((898571.7 6450681.8, 898578.4 6450678.5, 898581.2 6450673.4, 898579.6 6450670.5, 898575.9 6450672.3, 898568.8 6450675.7, 898571.7 6450681.8)))','2023-09-20 11:39:39.335','2023-09-20 11:39:39.335');
        ''')

    def test1(self):
        # je vérifie que la base ne contient bien uniquement les buildings que j'ai inséré avec setUpTestData
        assert len(Building.objects.all()) == 27
        
    def testGetBuilding(self):
        from batid.services.search_bdg import BuildingGuess
        search = BuildingGuess()
        search.set_params(**{"rnb_id":"Z39URVDZ9A39"})
        qs = search.get_queryset()
        assert len(qs) == 1

# %%
def test_runner(test_class):
    import unittest
    from django.test.utils import setup_test_environment, teardown_test_environment
    from django.test.runner import DiscoverRunner
    setup_test_environment()
    runner = DiscoverRunner(verbosity=1, interactive=True, failfast=True)
    suite = unittest.TestLoader().loadTestsFromTestCase(test_class)
    result = runner.run_suite(suite)
    runner.suite_result(suite, result)
    teardown_test_environment()

# %%
test_runner(MyTests)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.245s
#
# OK
